# %% [markdown]
# <img src="img.jpg">
#
# # Workout Classification
# Now it's possible to collect a large amount of data about personal movement using activity monitoring devices such as a [Fitbit](http://www.fitbit.com), [NikeFuelband](http://www.nike.com/us/en_us/c/nikeplus-fuelband), or [Jawbone Up](https://jawbone.com/up). These type of devices are part of the "quantified self" movement, a group of enthusiasts who take measurements about themselves regularly to improve their health or to find patterns in their behavior. Unfurtunatelly, these data remain under-utilized both because the raw data are hard to obtain and there is a lack of statistical methods and software for processing and interpreting the data.
#
# Usually, people quantify the amount of exercise they do but don't the quality of it. The objective of this project is to use the data from accelerometers on the belt, forearm, arm, and dumbbell to classify when an exercise is done correctly or not.
#
# This project is structured as follows:
# 1. [Understanding the Data](#Understanding_the_Data)
#     1. [Descriptive and Exploratory Analysis](#Descriptive_and_Exploratory_Analysis)
#         1. [Anomaly Detection](#Anomaly_Detection)
#     2. [Training and Validation Dataset](#Training_and_Validation_Dataset)
# 2. [Feature Selection/Importance](#Feature_Selection_Importance)
# 3. [Classification Model](#Classification_Model)
# 4. [Conclusions and Remarks](#Conclusions_and_Remarks)
# 5. [Supplementary Information](#Supplementary_Information)

# %% [markdown]
# ## Understanding the Data
# <a id='Understanding_the_Data'></a>
#
# This project is possible thanks to the data obtained from [here](http://groupware.les.inf.puc-rio.br/har#weight_lifting_exercises). Also, the owners of this dataset have an [available publication](http://groupware.les.inf.puc-rio.br/public/papers/2013.Velloso.QAR-WLE.pdf).
#
# The experimental design was conducted in accordance with the next points:
# 1. The exercises were performed by 6 young (20-28 years old) healthy participants.
# 2. Each participant did 10 repetitions of "Unilateral Dumbbell Biceps Curl" in 5 different fashions:
#     1. _Class A_: Exactly as the specifications (high quality performance)
#     2. _Class B_: Throwing the elbows to the front (mistake).
#     3. _Class C_: Lifting the dumbbell only halfway (mistake).
#     4. _Class D_: Lowering the dumbbell only halfway (mistake).
#     5. _Class E_: Throwing the hips to the front (mistake).
# 3. Four sensors were used to collect the data (in the glove, armband, lumbar belt and dumbbell), as it is represented in the below figure (this figure was inspired by the schema proposed by the author [here](http://groupware.les.inf.puc-rio.br/public/papers/2013.Velloso.QAR-WLE.pdf)).
# 4. Each sensor acts as a center of a euclidean coordinates system, so, for each sensor was possible to record it's [intrinsic rotations](https://en.wikipedia.org/wiki/Euler_angles) (yaw, pitch, and roll), in addition to the [gyroscope](https://en.wikipedia.org/wiki/Gyroscope), [accelerometer](https://en.wikipedia.org/wiki/Accelerometer), and [magnetometer](https://en.wikipedia.org/wiki/Magnetometer) values for each axis of the coordinate system.
#
# <img src="workout_body.png">
#
# More details about this data can be consulted [here](http://groupware.les.inf.puc-rio.br/har#weight_lifting_exercises).

# %% [markdown]
# ## Descriptive and Exploratory Analysis
# <a id='Descriptive_and_Exploratory_Analysis'></a>

# %%
# Load Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
# Load Dataset
raw_data=pd.read_csv('WearableComputing_weight_lifting_exercises_biceps_curl_variations.csv',low_memory=False)
# Make a copy of the data
curl_variation=raw_data.copy()
print('The dataset is composed by {} instances and {} features.'.format(
    curl_variation.shape[0],curl_variation.shape[1]))
# Out:
# The dataset is composed by 39242 instances and 159 features.

# %%
# Get some information about the dataset
curl_variation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39242 entries, 0 to 39241
# Columns: 159 entries, user_name to classe
# dtypes: float64(99), int64(23), object(37)
# memory usage: 47.6+ MB

# %% [markdown]
# The target variable is `classe`, and as we can see below, there is a little imbalance between class A and the other classes that we need to take care of. Nevertheless, by the moment lets put the target variable out of the dataset.

# %%
# Count the categories frequency of the target variable
curl_variation['classe'].value_counts()
# Out:
# A    11159
# B     7593
# E     7214
# C     6844
# D     6432
# Name: classe, dtype: int64

# %%
# Create the target and explanation dataset
y = curl_variation['classe']
X = curl_variation.drop(columns='classe')

# %% [markdown]
# Before going forward, lets split the dataset to create a test set that we only are going to use at the end of the analysis to prove the efficiency of the predictive algorithm. Because I want to keep the proportion of classes of the original dataset in the test data, I am not going to use the classical `train_test_split` method in sklearn, but the method `StratifiedShuffleSplit`.

# %%
# Create a test dataset
from sklearn.model_selection import StratifiedShuffleSplit
# Create an object StratifiedShuffleSplit
stratSplit = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# Create the training and testing dataset
for train_index, test_index in stratSplit.split(X, y):
    X_train, X_test = X.loc[train_index,:], X.loc[test_index,:]
    y_train, y_test = y[train_index], y[test_index]
print('The training data is composed by {} observations and {} variables.'.format(X_train.shape[0],
                                                                                 X_train.shape[1]))
print('The test data is composed by {} observations and {} variables.'.format(X_test.shape[0],
                                                                                 X_test.shape[1]))
# Out:
# The training data is composed by 31393 observations and 158 variables.
# The test data is composed by 7849 observations and 158 variables.

# %% [markdown]
# Also, I am going to split the current training dataset in `validation` and `train`. The validation dataset is going to be used for the parameter tuning.

# %%
from sklearn.model_selection import train_test_split
# Split the train and test dataset
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2,random_state=1)

# %% [markdown]
# In all the following sections we are going to work only on the `X_train`, `y_train` dataset. For each modification of the training data, I am going to do the same modification in the validation data, with the difference that in the last case I am going to use the functions implemented in the file `functions.py`. This is going to work also as a proof of concept for each function that will be enrolled in the final data cleaning function.

# %%
# Display the head of our data frame
pd.set_option('display.max_columns',None)
X_train.head()
# Out:
#       user_name  raw_timestamp_part_1  raw_timestamp_part_2    cvtd_timestamp  \
# 36557    eurico            1322489664                218625  28/11/2011 14:14
# 13155    eurico            1322489703                734687  28/11/2011 14:15
# 20336    jeremy            1322673080                842742  30/11/2011 17:11
# 17667  carlitos            1323084316                292315  05/12/2011 11:25
# 10556    eurico            1322489637                174724  28/11/2011 14:13
#
#       new_window  num_window  roll_belt  pitch_belt  yaw_belt  \
# 36557         no         806       1.10        2.53     -89.0
# 13155         no         292     -23.60       -3.00     -88.9
# 20336         no         443       1.00        3.35     -88.0
# 17667         no         388       1.36        6.95     -93.6
# 10556         no         237       1.40        3.53     -88.8
#
#        total_accel_belt kurtosis_roll_belt kurtosis_picth_belt  \
# 36557                 2                NaN                 NaN
# 13155                10                NaN                 NaN
# 20336                 4                NaN                 NaN
# 17667                 3                NaN                 NaN
# 10556                 3                NaN                 NaN
#
#       kurtosis_yaw_belt skewness_roll_belt skewness_roll_belt.1  \
# 36557               NaN                NaN                  NaN
# 13155               NaN                NaN                  NaN
# 20336               NaN                NaN                  NaN
# 17667               NaN                NaN                  NaN
# 10556               NaN                NaN                  NaN
#
#       skewness_yaw_belt  max_roll_belt  max_picth_belt max_yaw_belt  \
# 36557               NaN            NaN             NaN          NaN
# 13155               NaN            NaN             NaN          NaN
# 20336               NaN            NaN             NaN          NaN
# 17667               NaN            NaN             NaN          NaN
# 10556               NaN            NaN             NaN          NaN
#
#        min_roll_belt  min_pitch_belt min_yaw_belt  amplitude_roll_belt  \
# 36557            NaN             NaN          NaN                  NaN
# 13155            NaN             NaN          NaN                  NaN
# 20336            NaN             NaN          NaN                  NaN
# 17667            NaN             NaN          NaN                  NaN
# 10556            NaN             NaN          NaN                  NaN
#
#        amplitude_pitch_belt amplitude_yaw_belt  var_total_accel_belt  \
# 36557                   NaN                NaN                   NaN
# 13155                   NaN                NaN                   NaN
# 20336                   NaN                NaN                   NaN
# 17667                   NaN                NaN                   NaN
# 10556                   NaN                NaN                   NaN
#
#        avg_roll_belt  stddev_roll_belt  var_roll_belt  avg_pitch_belt  \
# 36557            NaN               NaN            NaN             NaN
# 13155            NaN               NaN            NaN             NaN
# 20336            NaN               NaN            NaN             NaN
# 17667            NaN               NaN            NaN             NaN
# 10556            NaN               NaN            NaN             NaN
#
#        stddev_pitch_belt  var_pitch_belt  avg_yaw_belt  stddev_yaw_belt  \
# 36557                NaN             NaN           NaN              NaN
# 13155                NaN             NaN           NaN              NaN
# 20336                NaN             NaN           NaN              NaN
# 17667                NaN             NaN           NaN              NaN
# 10556                NaN             NaN           NaN              NaN
#
#        var_yaw_belt  gyros_belt_x  gyros_belt_y  gyros_belt_z  accel_belt_x  \
# 36557           NaN         -0.05          0.02         -0.03            -4
# 13155           NaN         -0.16         -0.13         -0.30           -28
# 20336           NaN          0.16          0.03          0.02           -15
# 17667           NaN          0.02          0.02         -0.05           -17
# 10556           NaN         -0.02          0.00         -0.03            -9
#
#        accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 36557            -1            23             27            573
# 13155            -6            91            -37            657
# 20336             7            40             44            632
# 17667             4            21              0            598
# 10556             5            26             36            574
#
#        magnet_belt_z  roll_arm  pitch_arm  yaw_arm  total_accel_arm  \
# 36557           -433     143.0      -5.15   -105.0               57
# 13155           -223      97.1     -13.80     31.2               19
# 20336           -300       0.0       0.00      0.0               31
# 17667           -310      71.8      14.90    100.0               31
# 10556           -430      76.8     -26.30     44.1               16
#
#        var_accel_arm  avg_roll_arm  stddev_roll_arm  var_roll_arm  \
# 36557            NaN           NaN              NaN           NaN
# 13155            NaN           NaN              NaN           NaN
# 20336            NaN           NaN              NaN           NaN
# 17667            NaN           NaN              NaN           NaN
# 10556            NaN           NaN              NaN           NaN
#
#        avg_pitch_arm  stddev_pitch_arm  var_pitch_arm  avg_yaw_arm  \
# 36557            NaN               NaN            NaN          NaN
# 13155            NaN               NaN            NaN          NaN
# 20336            NaN               NaN            NaN          NaN
# 17667            NaN               NaN            NaN          NaN
# 10556            NaN               NaN            NaN          NaN
#
#        stddev_yaw_arm  var_yaw_arm  gyros_arm_x  gyros_arm_y  gyros_arm_z  \
# 36557             NaN          NaN         1.89        -0.74         0.13
# 13155             NaN          NaN         3.89        -1.57         0.07
# 20336             NaN          NaN        -3.24         1.64        -0.13
# 17667             NaN          NaN         1.56        -0.56         0.34
# 10556             NaN          NaN         3.23        -0.92         0.34
#
#        accel_arm_x  accel_arm_y  accel_arm_z  magnet_arm_x  magnet_arm_y  \
# 36557          -83          -44         -547          -232          -201
# 13155          -21          187          -13           647            78
# 20336           79           27         -291           595          -189
# 17667         -264          138          -54          -286           334
# 10556           17          154          -45           583            37
#
#        magnet_arm_z kurtosis_roll_arm kurtosis_picth_arm kurtosis_yaw_arm  \
# 36557          -496               NaN                NaN              NaN
# 13155           267               NaN                NaN              NaN
# 20336          -342               NaN                NaN              NaN
# 17667           547               NaN                NaN              NaN
# 10556           387               NaN                NaN              NaN
#
#       skewness_roll_arm skewness_pitch_arm skewness_yaw_arm  max_roll_arm  \
# 36557               NaN                NaN              NaN           NaN
# 13155               NaN                NaN              NaN           NaN
# 20336               NaN                NaN              NaN           NaN
# 17667               NaN                NaN              NaN           NaN
# 10556               NaN                NaN              NaN           NaN
#
#        max_picth_arm  max_yaw_arm  min_roll_arm  min_pitch_arm  min_yaw_arm  \
# 36557            NaN          NaN           NaN            NaN          NaN
# 13155            NaN          NaN           NaN            NaN          NaN
# 20336            NaN          NaN           NaN            NaN          NaN
# 17667            NaN          NaN           NaN            NaN          NaN
# 10556            NaN          NaN           NaN            NaN          NaN
#
#        amplitude_roll_arm  amplitude_pitch_arm  amplitude_yaw_arm  \
# 36557                 NaN                  NaN                NaN
# 13155                 NaN                  NaN                NaN
# 20336                 NaN                  NaN                NaN
# 17667                 NaN                  NaN                NaN
# 10556                 NaN                  NaN                NaN
#
#        roll_dumbbell  pitch_dumbbell  yaw_dumbbell kurtosis_roll_dumbbell  \
# 36557      -1.714818       38.681582    118.355989                    NaN
# 13155      52.660030       16.832614    101.245058                    NaN
# 20336      84.399179      -37.280696    -58.928443                    NaN
# 17667      88.276474       11.058202     67.558652                    NaN
# 10556    -114.746433      -41.720984     -6.758665                    NaN
#
#       kurtosis_picth_dumbbell kurtosis_yaw_dumbbell skewness_roll_dumbbell  \
# 36557                     NaN                   NaN                    NaN
# 13155                     NaN                   NaN                    NaN
# 20336                     NaN                   NaN                    NaN
# 17667                     NaN                   NaN                    NaN
# 10556                     NaN                   NaN                    NaN
#
#       skewness_pitch_dumbbell skewness_yaw_dumbbell  max_roll_dumbbell  \
# 36557                     NaN                   NaN                NaN
# 13155                     NaN                   NaN                NaN
# 20336                     NaN                   NaN                NaN
# 17667                     NaN                   NaN                NaN
# 10556                     NaN                   NaN                NaN
#
#        max_picth_dumbbell max_yaw_dumbbell  min_roll_dumbbell  \
# 36557                 NaN              NaN                NaN
# 13155                 NaN              NaN                NaN
# 20336                 NaN              NaN                NaN
# 17667                 NaN              NaN                NaN
# 10556                 NaN              NaN                NaN
#
#        min_pitch_dumbbell min_yaw_dumbbell  amplitude_roll_dumbbell  \
# 36557                 NaN              NaN                      NaN
# 13155                 NaN              NaN                      NaN
# 20336                 NaN              NaN                      NaN
# 17667                 NaN              NaN                      NaN
# 10556                 NaN              NaN                      NaN
#
#        amplitude_pitch_dumbbell amplitude_yaw_dumbbell  total_accel_dumbbell  \
# 36557                       NaN                    NaN                     6
# 13155                       NaN                    NaN                    10
# 20336                       NaN                    NaN                    32
# 17667                       NaN                    NaN                     3
# 10556                       NaN                    NaN                     3
#
#        var_accel_dumbbell  avg_roll_dumbbell  stddev_roll_dumbbell  \
# 36557                 NaN                NaN                   NaN
# 13155                 NaN                NaN                   NaN
# 20336                 NaN                NaN                   NaN
# 17667                 NaN                NaN                   NaN
# 10556                 NaN                NaN                   NaN
#
#        var_roll_dumbbell  avg_pitch_dumbbell  stddev_pitch_dumbbell  \
# 36557                NaN                 NaN                    NaN
# 13155                NaN                 NaN                    NaN
# 20336                NaN                 NaN                    NaN
# 17667                NaN                 NaN                    NaN
# 10556                NaN                 NaN                    NaN
#
#        var_pitch_dumbbell  avg_yaw_dumbbell  stddev_yaw_dumbbell  \
# 36557                 NaN               NaN                  NaN
# 13155                 NaN               NaN                  NaN
# 20336                 NaN               NaN                  NaN
# 17667                 NaN               NaN                  NaN
# 10556                 NaN               NaN                  NaN
#
#        var_yaw_dumbbell  gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 36557               NaN              0.42             -0.45             -0.92
# 13155               NaN             -0.40              0.56              0.03
# 20336               NaN             -0.05              1.65              0.18
# 17667               NaN             -0.13             -0.02              0.31
# 10556               NaN              0.16             -0.31             -0.25
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 36557                22                -1                54
# 13155                16                48                81
# 20336              -116               238              -177
# 17667                 3                21                17
# 10556               -12               -27                -2
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 36557             -345.0              230.0              387.0        -177.0
# 13155             -265.0              318.0              375.0        -176.0
# 20336             -249.0              565.0               62.0         165.0
# 17667             -524.0              335.0              -10.0         136.0
# 10556             -442.0              234.0              298.0         172.0
#
#        pitch_forearm  yaw_forearm kurtosis_roll_forearm  \
# 36557          11.70        113.0                   NaN
# 13155          18.00         14.1                   NaN
# 20336          38.30       -149.0                   NaN
# 17667           7.29         95.6                   NaN
# 10556          16.20        109.0                   NaN
#
#       kurtosis_picth_forearm kurtosis_yaw_forearm skewness_roll_forearm  \
# 36557                    NaN                  NaN                   NaN
# 13155                    NaN                  NaN                   NaN
# 20336                    NaN                  NaN                   NaN
# 17667                    NaN                  NaN                   NaN
# 10556                    NaN                  NaN                   NaN
#
#       skewness_pitch_forearm skewness_yaw_forearm  max_roll_forearm  \
# 36557                    NaN                  NaN               NaN
# 13155                    NaN                  NaN               NaN
# 20336                    NaN                  NaN               NaN
# 17667                    NaN                  NaN               NaN
# 10556                    NaN                  NaN               NaN
#
#        max_picth_forearm max_yaw_forearm  min_roll_forearm  min_pitch_forearm  \
# 36557                NaN             NaN               NaN                NaN
# 13155                NaN             NaN               NaN                NaN
# 20336                NaN             NaN               NaN                NaN
# 17667                NaN             NaN               NaN                NaN
# 10556                NaN             NaN               NaN                NaN
#
#       min_yaw_forearm  amplitude_roll_forearm  amplitude_pitch_forearm  \
# 36557             NaN                     NaN                      NaN
# 13155             NaN                     NaN                      NaN
# 20336             NaN                     NaN                      NaN
# 17667             NaN                     NaN                      NaN
# 10556             NaN                     NaN                      NaN
#
#       amplitude_yaw_forearm  total_accel_forearm  var_accel_forearm  \
# 36557                   NaN                   40                NaN
# 13155                   NaN                   31                NaN
# 20336                   NaN                   22                NaN
# 17667                   NaN                   38                NaN
# 10556                   NaN                   36                NaN
#
#        avg_roll_forearm  stddev_roll_forearm  var_roll_forearm  \
# 36557               NaN                  NaN               NaN
# 13155               NaN                  NaN               NaN
# 20336               NaN                  NaN               NaN
# 17667               NaN                  NaN               NaN
# 10556               NaN                  NaN               NaN
#
#        avg_pitch_forearm  stddev_pitch_forearm  var_pitch_forearm  \
# 36557                NaN                   NaN                NaN
# 13155                NaN                   NaN                NaN
# 20336                NaN                   NaN                NaN
# 17667                NaN                   NaN                NaN
# 10556                NaN                   NaN                NaN
#
#        avg_yaw_forearm  stddev_yaw_forearm  var_yaw_forearm  gyros_forearm_x  \
# 36557              NaN                 NaN              NaN             0.19
# 13155              NaN                 NaN              NaN            -0.34
# 20336              NaN                 NaN              NaN             0.06
# 17667              NaN                 NaN              NaN            -0.05
# 10556              NaN                 NaN              NaN            -0.24
#
#        gyros_forearm_y  gyros_forearm_z  accel_forearm_x  accel_forearm_y  \
# 36557            -1.16             0.03            -73.0            330.0
# 13155            -4.27            -0.92             74.0            262.0
# 20336            -4.29            -1.90            -66.0             22.0
# 17667             0.00            -0.02            127.0            270.0
# 10556            -0.24             0.33            -69.0            286.0
#
#        accel_forearm_z  magnet_forearm_x  magnet_forearm_y  magnet_forearm_z
# 36557              207            -790.0            1180.0            -546.0
# 13155              133             236.0             143.0            -280.0
# 20336             -208            -454.0            -279.0             311.0
# 17667             -221            -207.0             705.0             407.0
# 10556              203            -685.0            1150.0            -528.0

# %% [markdown]
# If you explore the above table, you can see that a lot of variables have not assigned values at least in the first 5 instances. Therefore, let's see what is the average of NaN for each feature in our dataset and erase the variables with more than 40% of missing values.
# > This threshold was selected taking into account that best algorithms/methods have a breaking point of 50%, this is, it's necessary at least 50% of the data in the distribution to make relative accurate estimations (for example the median). If we are going to impute the missing values, we need enough information in the variable, otherwise, it's better to drop the variable.

# %%
# Compute the average of rows with missing values per variable and only keep columns with 60%+ of information
pd.set_option('display.max_rows',None)
columns_out=X_train.columns[(X_train.isna().sum()/len(X_train)>0.4).values]
print('The {}% of the variables have more than 40% of the observations as NaN.'.format(
    round(100*len(columns_out)/X_train.shape[1],2)))
# Out:
# The 63.29% of the variables have more than 40% of the observations as NaN.

# %%
# Drop the columns with more than 40% of missing data
X_train.drop(columns=columns_out,inplace=True)
print('Now our data is composed by {} observations and {} variables. This is \
a hugh reduction of dimensionaity.'.format(
    X_train.shape[0],X_train.shape[1]))
X_train.head()
# Out:
# Now our data is composed by 25114 observations and 58 variables. This is a hugh reduction of dimensionaity.
#       user_name  raw_timestamp_part_1  raw_timestamp_part_2    cvtd_timestamp  \
# 36557    eurico            1322489664                218625  28/11/2011 14:14
# 13155    eurico            1322489703                734687  28/11/2011 14:15
# 20336    jeremy            1322673080                842742  30/11/2011 17:11
# 17667  carlitos            1323084316                292315  05/12/2011 11:25
# 10556    eurico            1322489637                174724  28/11/2011 14:13
#
#       new_window  num_window  roll_belt  pitch_belt  yaw_belt  \
# 36557         no         806       1.10        2.53     -89.0
# 13155         no         292     -23.60       -3.00     -88.9
# 20336         no         443       1.00        3.35     -88.0
# 17667         no         388       1.36        6.95     -93.6
# 10556         no         237       1.40        3.53     -88.8
#
#        total_accel_belt  gyros_belt_x  gyros_belt_y  gyros_belt_z  \
# 36557                 2         -0.05          0.02         -0.03
# 13155                10         -0.16         -0.13         -0.30
# 20336                 4          0.16          0.03          0.02
# 17667                 3          0.02          0.02         -0.05
# 10556                 3         -0.02          0.00         -0.03
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 36557            -4            -1            23             27            573
# 13155           -28            -6            91            -37            657
# 20336           -15             7            40             44            632
# 17667           -17             4            21              0            598
# 10556            -9             5            26             36            574
#
#        magnet_belt_z  roll_arm  pitch_arm  yaw_arm  total_accel_arm  \
# 36557           -433     143.0      -5.15   -105.0               57
# 13155           -223      97.1     -13.80     31.2               19
# 20336           -300       0.0       0.00      0.0               31
# 17667           -310      71.8      14.90    100.0               31
# 10556           -430      76.8     -26.30     44.1               16
#
#        gyros_arm_x  gyros_arm_y  gyros_arm_z  accel_arm_x  accel_arm_y  \
# 36557         1.89        -0.74         0.13          -83          -44
# 13155         3.89        -1.57         0.07          -21          187
# 20336        -3.24         1.64        -0.13           79           27
# 17667         1.56        -0.56         0.34         -264          138
# 10556         3.23        -0.92         0.34           17          154
#
#        accel_arm_z  magnet_arm_x  magnet_arm_y  magnet_arm_z  roll_dumbbell  \
# 36557         -547          -232          -201          -496      -1.714818
# 13155          -13           647            78           267      52.660030
# 20336         -291           595          -189          -342      84.399179
# 17667          -54          -286           334           547      88.276474
# 10556          -45           583            37           387    -114.746433
#
#        pitch_dumbbell  yaw_dumbbell  total_accel_dumbbell  gyros_dumbbell_x  \
# 36557       38.681582    118.355989                     6              0.42
# 13155       16.832614    101.245058                    10             -0.40
# 20336      -37.280696    -58.928443                    32             -0.05
# 17667       11.058202     67.558652                     3             -0.13
# 10556      -41.720984     -6.758665                     3              0.16
#
#        gyros_dumbbell_y  gyros_dumbbell_z  accel_dumbbell_x  accel_dumbbell_y  \
# 36557             -0.45             -0.92                22                -1
# 13155              0.56              0.03                16                48
# 20336              1.65              0.18              -116               238
# 17667             -0.02              0.31                 3                21
# 10556             -0.31             -0.25               -12               -27
#
#        accel_dumbbell_z  magnet_dumbbell_x  magnet_dumbbell_y  \
# 36557                54             -345.0              230.0
# 13155                81             -265.0              318.0
# 20336              -177             -249.0              565.0
# 17667                17             -524.0              335.0
# 10556                -2             -442.0              234.0
#
#        magnet_dumbbell_z  roll_forearm  pitch_forearm  yaw_forearm  \
# 36557              387.0        -177.0          11.70        113.0
# 13155              375.0        -176.0          18.00         14.1
# 20336               62.0         165.0          38.30       -149.0
# 17667              -10.0         136.0           7.29         95.6
# 10556              298.0         172.0          16.20        109.0
#
#        total_accel_forearm  gyros_forearm_x  gyros_forearm_y  gyros_forearm_z  \
# 36557                   40             0.19            -1.16             0.03
# 13155                   31            -0.34            -4.27            -0.92
# 20336                   22             0.06            -4.29            -1.90
# 17667                   38            -0.05             0.00            -0.02
# 10556                   36            -0.24            -0.24             0.33
#
#        accel_forearm_x  accel_forearm_y  accel_forearm_z  magnet_forearm_x  \
# 36557            -73.0            330.0              207            -790.0
# 13155             74.0            262.0              133             236.0
# 20336            -66.0             22.0             -208            -454.0
# 17667            127.0            270.0             -221            -207.0
# 10556            -69.0            286.0              203            -685.0
#
#        magnet_forearm_y  magnet_forearm_z
# 36557            1180.0            -546.0
# 13155             143.0            -280.0
# 20336            -279.0             311.0
# 17667             705.0             407.0
# 10556            1150.0            -528.0

# %%
# Check if exist other variable with NaN
var_with_nan=X_train.isna().sum()[X_train.isna().sum()!=0]
print('The remain variables with not assigned value are {} with {} missing values'.format(var_with_nan.index,
                                                                                        var_with_nan.values))
# Out:
# The remain variables with not assigned value are Index(['roll_dumbbell'], dtype='object') with [1] missing values

# %% [markdown]
# The above piece of information is important and we need to keep it in mind, but, for the moment let's see what is the datatype of our variables and convert the features to the correct datatype. After that, we can design a strategy to deal with this missing value.
#
# If you print the data type of each variable (use `curl_variation.dtypes`), you can see that there are only 3 types of formats in our dataset (`int`, `float`, `object`). The below code print the variables that belongs to each format.

# %%
# Print out the variables data type
dictionary={types: X_train.select_dtypes(types).columns for types in ['object','int','float']}
dictionary
# Out:
# {'object': Index(['user_name', 'cvtd_timestamp', 'new_window'], dtype='object'),
#  'int': Index(['raw_timestamp_part_1', 'raw_timestamp_part_2', 'num_window',
#         'total_accel_belt', 'accel_belt_x', 'accel_belt_y', 'accel_belt_z',
#         'magnet_belt_x', 'magnet_belt_y', 'magnet_belt_z', 'total_accel_arm',
#         'accel_arm_x', 'accel_arm_y', 'accel_arm_z', 'magnet_arm_x',
#         'magnet_arm_y', 'magnet_arm_z', 'total_accel_dumbbell',
#         'accel_dumbbell_x', 'accel_dumbbell_y', 'accel_dumbbell_z',
#         'total_accel_forearm', 'accel_forearm_z'],
#        dtype='object'),
#  'float': Index(['roll_belt', 'pitch_belt', 'yaw_belt', 'gyros_belt_x', 'gyros_belt_y',
#         'gyros_belt_z', 'roll_arm', 'pitch_arm', 'yaw_arm', 'gyros_arm_x',
#         'gyros_arm_y', 'gyros_arm_z', 'roll_dumbbell', 'pitch_dumbbell',
#         'yaw_dumbbell', 'gyros_dumbbell_x', 'gyros_dumbbell_y',
#         'gyros_dumbbell_z', 'magnet_dumbbell_x', 'magnet_dumbbell_y',
#         'magnet_dumbbell_z', 'roll_forearm', 'pitch_forearm', 'yaw_forearm',
#         'gyros_forearm_x', 'gyros_forearm_y', 'gyros_forearm_z',
#         'accel_forearm_x', 'accel_forearm_y', 'magnet_forearm_x',
#         'magnet_forearm_y', 'magnet_forearm_z'],
#        dtype='object')}

# %% [markdown]
# The above dictionary shows that the variables in the `float` data type group are correctly assigned, but in the object variables some features are `datetime` and others are `categories` (factor variables). We also have a similar situation with some variables in the group `int`. Let's transform these variables to the correct type.

# %%
# Transform to datetime
date_time_var=['cvtd_timestamp','raw_timestamp_part_1',
           'raw_timestamp_part_2']
X_train.loc[:,date_time_var]=X_train.loc[:,date_time_var].apply(pd.to_datetime)
# Transform to category
categories=['user_name','new_window']
X_train.loc[:,categories]=X_train.loc[:,categories].astype('category')
dictionary={types: X_train.select_dtypes(types).columns for types in ['object','int','float','category']}
dictionary
# Out:
# {'object': Index([], dtype='object'),
#  'int': Index(['num_window', 'total_accel_belt', 'accel_belt_x', 'accel_belt_y',
#         'accel_belt_z', 'magnet_belt_x', 'magnet_belt_y', 'magnet_belt_z',
#         'total_accel_arm', 'accel_arm_x', 'accel_arm_y', 'accel_arm_z',
#         'magnet_arm_x', 'magnet_arm_y', 'magnet_arm_z', 'total_accel_dumbbell',
#         'accel_dumbbell_x', 'accel_dumbbell_y', 'accel_dumbbell_z',
#         'total_accel_forearm', 'accel_forearm_z'],
#        dtype='object'),
#  'float': Index(['roll_belt', 'pitch_belt', 'yaw_belt', 'gyros_belt_x', 'gyros_belt_y',
#         'gyros_belt_z', 'roll_arm', 'pitch_arm', 'yaw_arm', 'gyros_arm_x',
#         'gyros_arm_y', 'gyros_arm_z', 'roll_dumbbell', 'pitch_dumbbell',
#         'yaw_dumbbell', 'gyros_dumbbell_x', 'gyros_dumbbell_y',
#         'gyros_dumbbell_z', 'magnet_dumbbell_x', 'magnet_dumbbell_y',
#         'magnet_dumbbell_z', 'roll_forearm', 'pitch_forearm', 'yaw_forearm',
#         'gyros_forearm_x', 'gyros_forearm_y', 'gyros_forearm_z',
#         'accel_forearm_x', 'accel_forearm_y', 'magnet_forearm_x',
#         'magnet_forearm_y', 'magnet_forearm_z'],
#        dtype='object'),
#  'category': Index(['user_name', 'new_window'], dtype='object')}

# %% [markdown]
# Now, the types of the variable looks that should and we can move back to our missing value. The first step is to look at the class that this missing value belongs to (this isn't necessary because we have only one missing value).

# %%
# Look at the class that belongs the missing value
y_train.loc[X_train['roll_dumbbell'].isna().values]
# Out:
# 8136    A
# Name: classe, dtype: object

# %% [markdown]
# As we can see, this missing value belong to class A, and the number of instances in this class is 7183 (see below), so, as was discussed before, one option is to erase this observation from the data, but also it is possible to impute this value using the `median`. In any case, given the amount of data in this class and the number of missing values, neither of the strategies is going to affect deeply the performance of a future ML algorithm.

# %%
# Print the number of instances by classes
print(y_train.value_counts())
# Out:
# A    7183
# B    4839
# E    4650
# C    4380
# D    4062
# Name: classe, dtype: int64

# %%
from sklearn.impute import SimpleImputer
# Define a SimpleImputer object
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer.fit(X_train[dictionary['float']])
# Impute the missing values in the training dataset
X_train[dictionary['float']]=imputer.transform(X_train[dictionary['float']])
# Print result
print('The number of missing values in our data is: {}'.format(X_train.isna().sum().sum()))
# Out:
# The number of missing values in our data is: 0

# %% [markdown]
# We know that our variables are related with the sensors data, but after erase some features, we don't know how many variables per sensor remains in the data frame. Below, you can see that the variables per location (13) are the same, given a total of 52 variables related with the reading of the sensor. The remaining 7 variables are descriptive in addition with the datetime and the target variable (`class`).

# %%
# Number of variables per sensor location
import re
pd.DataFrame({val: [string for string in X_train.columns if re.search(rf'\w*_{val}\w*', string)] for 
 val in ['belt','arm','forearm','dumbbell']})
# Out:
#                 belt              arm              forearm  \
# 0          roll_belt         roll_arm         roll_forearm
# 1         pitch_belt        pitch_arm        pitch_forearm
# 2           yaw_belt          yaw_arm          yaw_forearm
# 3   total_accel_belt  total_accel_arm  total_accel_forearm
# 4       gyros_belt_x      gyros_arm_x      gyros_forearm_x
# 5       gyros_belt_y      gyros_arm_y      gyros_forearm_y
# 6       gyros_belt_z      gyros_arm_z      gyros_forearm_z
# 7       accel_belt_x      accel_arm_x      accel_forearm_x
# 8       accel_belt_y      accel_arm_y      accel_forearm_y
# 9       accel_belt_z      accel_arm_z      accel_forearm_z
# 10     magnet_belt_x     magnet_arm_x     magnet_forearm_x
# 11     magnet_belt_y     magnet_arm_y     magnet_forearm_y
# 12     magnet_belt_z     magnet_arm_z     magnet_forearm_z
#
#                 dumbbell
# 0          roll_dumbbell
# 1         pitch_dumbbell
# 2           yaw_dumbbell
# 3   total_accel_dumbbell
# 4       gyros_dumbbell_x
# 5       gyros_dumbbell_y
# 6       gyros_dumbbell_z
# 7       accel_dumbbell_x
# 8       accel_dumbbell_y
# 9       accel_dumbbell_z
# 10     magnet_dumbbell_x
# 11     magnet_dumbbell_y
# 12     magnet_dumbbell_z

# %% [markdown]
# The descriptive table below provides a lot of useful information but in my opinion, an important point is to note that the values from different devices (accelerometer, gyroscope, ...) are recorded in different scales. The owners of this dataset don't specify the measure units of the devices, but after a little research I am pretty sure that our variables are recorded using the next units:
# * Accelerometer: Meters per second squared ($m/s^2$).
# * Gyroscope: Degrees per second ($^o/s$).
# * Magenetometer: Microtesla ($\mu T$).
# * pitch, roll \& yaw: Grades ($^o$).
#
# You can obtain more information about these devices [here](https://www.sparkfun.com/products/retired/10736).

# %%
# Describe the numerical variables
X_train.describe()
# Out:
#         num_window     roll_belt    pitch_belt      yaw_belt  \
# count  25114.00000  25114.000000  25114.000000  25114.000000
# mean     434.12065     65.153286      0.389593    -10.553689
# std      247.90118     62.692818     22.425087     95.041663
# min        1.00000    -28.800000    -56.200000   -180.000000
# 25%      223.00000      1.100000      1.830000    -88.200000
# 50%      431.00000    115.000000      5.320000    -11.600000
# 75%      650.00000    123.000000     15.500000     13.200000
# max      864.00000    162.000000     60.300000    180.000000
#
#        total_accel_belt  gyros_belt_x  gyros_belt_y  gyros_belt_z  \
# count      25114.000000  25114.000000  25114.000000  25114.000000
# mean          11.409652     -0.006365      0.040077     -0.132024
# std            7.732974      0.207957      0.078633      0.236692
# min            0.000000     -1.030000     -0.640000     -1.570000
# 25%            3.000000     -0.030000      0.000000     -0.200000
# 50%           17.000000      0.030000      0.020000     -0.110000
# 75%           18.000000      0.110000      0.110000     -0.020000
# max           29.000000      2.220000      0.640000      1.610000
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# count  25114.000000  25114.000000  25114.000000   25114.000000   25114.000000
# mean      -5.623238     30.517082    -73.620172      55.897706     593.958549
# std       29.757103     28.649095    100.535631      64.720814      35.304866
# min     -120.000000    -69.000000   -276.000000     -55.000000     354.000000
# 25%      -21.000000      3.000000   -162.000000       9.000000     582.000000
# 50%      -15.000000     37.000000   -153.000000      35.000000     601.000000
# 75%       -5.000000     61.000000     28.000000      59.000000     610.000000
# max      106.000000    164.000000    108.000000     485.000000     675.000000
#
#        magnet_belt_z      roll_arm     pitch_arm       yaw_arm  \
# count   25114.000000  25114.000000  25114.000000  25114.000000
# mean     -345.107749     16.793323     -4.127290     -0.941945
# std        64.572040     72.688532     30.795025     71.798465
# min      -627.000000   -180.000000    -89.100000   -180.000000
# 25%      -375.000000    -33.100000    -25.475000    -43.500000
# 50%      -320.000000      0.000000      0.000000      0.000000
# 75%      -306.000000     77.000000     11.900000     45.900000
# max       291.000000    180.000000     88.500000    180.000000
#
#        total_accel_arm   gyros_arm_x   gyros_arm_y   gyros_arm_z  \
# count     25114.000000  25114.000000  25114.000000  25114.000000
# mean         25.423310      0.048725     -0.261160      0.273956
# std          10.448267      1.981931      0.847932      0.550025
# min           1.000000     -6.370000     -3.480000     -2.330000
# 25%          17.000000     -1.300000     -0.800000     -0.070000
# 50%          27.000000      0.080000     -0.240000      0.250000
# 75%          32.750000      1.560000      0.140000      0.720000
# max          67.000000      4.900000      2.830000      2.990000
#
#         accel_arm_x   accel_arm_y   accel_arm_z  magnet_arm_x  magnet_arm_y  \
# count  25114.000000  25114.000000  25114.000000  25114.000000  25114.000000
# mean     -62.497929     32.634785    -68.759736    185.900454    160.161066
# std      181.757392    109.682349    133.351723    443.227461    200.508242
# min     -428.000000   -318.000000   -636.000000   -584.000000   -392.000000
# 25%     -243.000000    -53.000000   -139.000000   -304.000000      0.000000
# 50%      -47.000000     13.000000    -44.000000    275.000000    209.000000
# 75%       82.000000    139.000000     24.000000    632.000000    324.000000
# max      437.000000    326.000000    292.000000    783.000000    581.000000
#
#        magnet_arm_z  roll_dumbbell  pitch_dumbbell  yaw_dumbbell  \
# count  25114.000000   25114.000000    25114.000000  25114.000000
# mean     312.836506      24.134255      -10.959351      1.276347
# std      323.274885      69.751034       36.955771     82.576074
# min     -597.000000    -154.139304     -149.593648   -152.826879
# 25%      150.000000     -17.740784      -41.344014    -77.496663
# 50%      448.000000      48.482080      -21.351573     -5.270063
# 75%      547.000000      67.729318       17.603959     80.366844
# max      703.000000     153.545571      149.402444    154.952294
#
#        total_accel_dumbbell  gyros_dumbbell_x  gyros_dumbbell_y  \
# count          25114.000000      25114.000000      25114.000000
# mean              13.786095          0.163858          0.045023
# std               10.258796          1.345114          0.583148
# min                0.000000       -204.000000         -2.120000
# 25%                5.000000         -0.030000         -0.140000
# 50%               10.000000          0.140000          0.050000
# 75%               20.000000          0.350000          0.210000
# max               58.000000          2.360000         52.000000
#
#        gyros_dumbbell_z  accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# count      25114.000000      25114.000000      25114.000000      25114.000000
# mean          -0.134447        -29.129888         53.312575        -38.736800
# std            2.026435         67.473041         80.853663        109.742649
# min           -2.380000       -419.000000       -183.000000       -334.000000
# 25%           -0.310000        -51.000000         -8.000000       -142.000000
# 50%           -0.130000         -9.000000         42.000000         -2.000000
# 75%            0.030000         11.000000        113.000000         37.000000
# max          317.000000        235.000000        302.000000        319.000000
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# count       25114.000000       25114.000000       25114.000000  25114.000000
# mean         -327.233561         220.982132          44.948767     33.894766
# std           341.210739         327.113943         139.534200    107.654978
# min          -643.000000       -3600.000000        -262.000000   -180.000000
# 25%          -535.000000         231.000000         -46.000000     -1.097500
# 50%          -478.000000         311.000000          13.000000     20.100000
# 75%          -306.000000         392.000000          96.000000    140.000000
# max           592.000000         633.000000         453.000000    180.000000
#
#        pitch_forearm   yaw_forearm  total_accel_forearm  gyros_forearm_x  \
# count   25114.000000  25114.000000         25114.000000     25114.000000
# mean       11.113305     19.297036            34.649319         0.142296
# std        28.163380    103.599164            10.088054         2.235682
# min       -72.500000   -180.000000             0.000000      -339.000000
# 25%         0.000000    -69.675000            29.000000        -0.220000
# 50%         9.905000      0.000000            36.000000         0.050000
# 75%        29.100000    111.000000            41.000000         0.560000
# max        89.800000    180.000000           108.000000         3.970000
#
#        gyros_forearm_y  gyros_forearm_z  accel_forearm_x  accel_forearm_y  \
# count     25114.000000     25114.000000     25114.000000     25114.000000
# mean          0.108722         0.151487       -64.904627       162.874118
# std           4.379529         1.609382       180.629412       199.467147
# min          -7.030000       -52.000000      -498.000000      -690.000000
# 25%          -1.450000        -0.180000      -182.000000        54.000000
# 50%           0.030000         0.080000       -59.000000       199.500000
# 75%           1.670000         0.490000        72.000000       313.000000
# max         516.000000       231.000000       479.000000       923.000000
#
#        accel_forearm_z  magnet_forearm_x  magnet_forearm_y  magnet_forearm_z
# count     25114.000000      25114.000000      25114.000000      25114.000000
# mean        -55.406785       -318.501023        379.697102        395.616092
# std         137.345571        346.069503        505.535081        368.592302
# min        -458.000000      -1280.000000       -906.000000       -973.000000
# 25%        -181.000000       -621.000000          8.000000        200.000000
# 50%         -39.500000       -390.000000        583.000000        514.000000
# 75%          25.000000        -78.000000        736.000000        653.000000
# max         287.000000        672.000000       1480.000000       1090.000000

# %% [markdown]
# #### Data Standarization
# Before going forward with anomaly detection, it's a good idea to standardize the data in order that each variable has the same scale. For this, we are going to fit the standardizer to the training data and use it in the future to standardize the validation and test dataset.

# %%
from sklearn.preprocessing import StandardScaler
# List the variables by type
type_var={types: X_train.select_dtypes(types).columns for types in ['datetime','int','float','category']}
# Only include the numeric variables (int and float)
numerical_X_train = X_train[type_var['float'].append(type_var['int'])]
# Create a StandardScaler object and fit it to the data
scaler=StandardScaler()
scaler.fit(numerical_X_train)
# Transform the data and storage in a data frame
standard_train_data=pd.DataFrame(scaler.transform(numerical_X_train),
                          columns=numerical_X_train.columns,
                          index=numerical_X_train.index) 
# List the variables that were not standarised
extra_var=type_var['category'].append(type_var['datetime'])
# Include the desciptive columns    
standard_train_data[extra_var]=X_train[extra_var]
# Shows the first rows to be sure everything looks good
X_train=standard_train_data.copy()
X_train.head()
# Out:
#        roll_belt  pitch_belt  yaw_belt  gyros_belt_x  gyros_belt_y  \
# 36557  -1.021721    0.095449 -0.825405     -0.209831     -0.255327
# 13155  -1.415713   -0.151155 -0.824353     -0.738796     -2.162953
# 20336  -1.023316    0.132016 -0.814883      0.800011     -0.128152
# 17667  -1.017574    0.292554 -0.873806      0.126783     -0.255327
# 10556  -1.016936    0.140043 -0.823301     -0.065568     -0.509678
#
#        gyros_belt_z  roll_arm  pitch_arm   yaw_arm  gyros_arm_x  gyros_arm_y  \
# 36557      0.431051  1.736301  -0.033211 -1.449336     0.929049    -0.564726
# 13155     -0.709694  1.104827  -0.314106  0.447678     1.938186    -1.543598
# 20336      0.642300 -0.231036   0.134027  0.013120    -1.659387     2.242158
# 17667      0.346552  0.756760   0.617881  1.405935     0.762542    -0.352441
# 10556      0.431051  0.825548  -0.720024  0.627351     1.605171    -0.777012
#
#        gyros_arm_z  roll_dumbbell  pitch_dumbbell  yaw_dumbbell  \
# 36557    -0.261731      -0.370598        1.343279      1.417868
# 13155    -0.370819       0.408974        0.752048      1.210650
# 20336    -0.734445       0.864018       -0.712253     -0.729097
# 17667     0.120078       0.919606        0.595793      0.802698
# 10556     0.120078      -1.991131       -0.832407     -0.097306
#
#        gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 36557          0.190427         -0.848897         -0.387661
# 13155         -0.419198          0.883116          0.081152
# 20336         -0.158992          2.752318          0.155175
# 17667         -0.218468         -0.111505          0.219329
# 10556         -0.002869         -0.608816         -0.057024
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 36557          -0.052070           0.027569           2.451428     -1.959027
# 13155           0.182394           0.296593           2.365426     -1.949737
# 20336           0.229287           1.051697           0.122204      1.217852
# 17667          -0.576683           0.348564          -0.393809      0.948468
# 10556          -0.336357           0.039797           1.813579      1.282876
#
#        pitch_forearm  yaw_forearm  gyros_forearm_x  gyros_forearm_y  \
# 36557       0.020832     0.904494         0.021338        -0.289700
# 13155       0.244531    -0.050166        -0.215731        -0.999836
# 20336       0.965340    -1.624534        -0.036811        -1.004402
# 17667      -0.135757     0.736536        -0.086014        -0.024826
# 10556       0.180617     0.865883        -0.171001        -0.079627
#
#        gyros_forearm_z  accel_forearm_x  accel_forearm_y  magnet_forearm_x  \
# 36557        -0.075488        -0.044818         0.837878         -1.362467
# 13155        -0.665789         0.769019         0.496963          1.602314
# 20336        -1.274730        -0.006064        -0.706266         -0.391545
# 17667        -0.106557         1.062443         0.537071          0.322199
# 10556         0.110923        -0.022673         0.617286         -1.059054
#
#        magnet_forearm_y  magnet_forearm_z  num_window  total_accel_belt  \
# 36557          1.583112         -2.554679    1.500141         -1.216846
# 13155         -0.468220         -1.833000   -0.573307         -0.182295
# 20336         -1.302996         -0.229570    0.035819         -0.958208
# 17667          0.643495          0.030885   -0.186048         -1.087527
# 10556          1.523768         -2.505843   -0.795174         -1.087527
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 36557      0.054551     -1.100129      0.961073      -0.446507      -0.593657
# 13155     -0.751996     -1.274658      1.637464      -1.435389       1.785666
# 20336     -0.315116     -0.820883      1.130171      -0.183835       1.077534
# 17667     -0.382328     -0.925600      0.941179      -0.863692       0.114475
# 10556     -0.113480     -0.890694      0.990914      -0.307445      -0.565331
#
#        magnet_belt_z  total_accel_arm  accel_arm_x  accel_arm_y  accel_arm_z  \
# 36557      -1.361177         3.022254    -0.112801    -0.698711    -3.586379
# 13155       1.891069        -0.614785     0.228319     1.407412     0.418149
# 20336       0.698579         0.533754     0.778514    -0.051375    -1.666605
# 17667       0.543710         0.533754    -1.108654     0.960659     0.110685
# 10556      -1.314717        -0.901920     0.437394     1.106537     0.178177
#
#        magnet_arm_x  magnet_arm_y  magnet_arm_z  total_accel_dumbbell  \
# 36557     -0.942877     -1.801264     -2.502058             -0.758983
# 13155      1.040343     -0.409772     -0.141791             -0.369066
# 20336      0.923020     -1.741415     -2.025674              1.775478
# 17667     -1.064713      0.867009      0.724362             -1.051421
# 10556      0.895945     -0.614257      0.229418             -1.051421
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 36557          0.757798         -0.671753          0.845056
# 13155          0.668871         -0.065707          1.091091
# 20336         -1.287504          2.284264         -1.259911
# 17667          0.476198         -0.399651          0.507897
# 10556          0.253883         -0.993328          0.334761
#
#        total_accel_forearm  accel_forearm_z user_name new_window  \
# 36557             0.530408         1.910597    eurico         no
# 13155            -0.361754         1.371799    eurico         no
# 20336            -1.253916        -1.111039    jeremy         no
# 17667             0.332150        -1.205692  carlitos         no
# 10556             0.133892         1.881473    eurico         no
#
#                raw_timestamp_part_1          raw_timestamp_part_2  \
# 36557 1970-01-01 00:00:01.322489664 1970-01-01 00:00:00.000218625
# 13155 1970-01-01 00:00:01.322489703 1970-01-01 00:00:00.000734687
# 20336 1970-01-01 00:00:01.322673080 1970-01-01 00:00:00.000842742
# 17667 1970-01-01 00:00:01.323084316 1970-01-01 00:00:00.000292315
# 10556 1970-01-01 00:00:01.322489637 1970-01-01 00:00:00.000174724
#
#            cvtd_timestamp
# 36557 2011-11-28 14:14:00
# 13155 2011-11-28 14:15:00
# 20336 2011-11-30 17:11:00
# 17667 2011-05-12 11:25:00
# 10556 2011-11-28 14:13:00

# %% [markdown]
# #### Anomaly Detection
# <a id='Anomaly_Detection'></a>
# At this point is important to clean out the training dataset of outliers. Outliers can be errors or could be interesting patterns that needs to be included and analyzed as such. Because our data is normalized we can use parametrics and noparametrics approaches with this aim, also, we can use univariate and multivariate alternatives.
#
# Boxplots are a simple alternative to obtain a general idea about the outliers distribution by feature. Also, it uses a "Interquantile Range Rule" (see below) to decide when a point is an outlier or not.
#
# > 1. **[Interquartile Range Rule](https://en.wikipedia.org/wiki/Interquartile_range)**: The data point into the interval $[Q1-1.5\times IQR, Q3+1.5\times IQR]$, where Q1 and Q3 are the first (25\% lies between the minimum and Q1) and third (75\% lies between the minimum and Q3) quartile, and IQR=Q3-Q1, are inliers, while the points out of this interval are outliers.
# 2. **[Isolation Forest](https://cs.nju.edu.cn/zhouzh/zhouzh.files/publication/icdm08b.pdf?q=isolation-forest)**: The idea here is to determine when an observation is an outlier based on the number of necessary binary partitions to isolate the observation. Outliers should be easily isolated (fewer partitions) while inliers will take more partitions steps.
#
# The boxplot below shows that some variables like `gyros_dumbell_x`, `gyros_dumbell_y`, `gyros_dumbell_z`, `gyros_forearm_x`, `gyros_forearm_y`, `gyros_forearm_z` have between 1 and 2 very extreme values. These few observations seems to be related with errors in the reading of the gyroscope, and for that reason, I belive that the best option is to dropp out these observations. Also, in all the others variables seems to be a lot of atypical values under the Interquantile Range Rule unbrella, in fact, approximatelly the 30\% of our observations have some outliers in at least one variable (see below). This percent seem to be a little excessive, so, it's necessary to get more information about the multivariate distribution of these observations. With this aim, we are going to use a Principal Component Analysis.

# %%
# Boxplot
plt.figure(figsize=(20,5))
X_train.boxplot(rot=90)

# %%
# Drop oout the observations in the gyroscope reading with very extreme values 
# (consider only the observations with values between -25 and 25)
index_condition=X_train[(X_train['gyros_dumbbell_x']<=-25) | 
                        (X_train['gyros_dumbbell_y']>=25)  |
                        (X_train['gyros_dumbbell_z']>=25)  |
                        (X_train['gyros_forearm_x']<= -25) |
                        (X_train['gyros_forearm_y']>= 25)  |
                        (X_train['gyros_forearm_z']<= -25) |
                        (X_train['gyros_forearm_z']>= 25)].index
# Drop the observations from the independent and dependent
X_train.drop(index_condition, inplace=True)
y_train.drop(index_condition,inplace=True)

# %% [markdown]
# Other ourliers detection alternatives like Isolation Forest, IQR rule, and Local Outlier Factor were implemented, but the classification results doesn't improve if we take into account these outliers. Nevertheless, I keep some of the implement code in this notebook as a reference (see the [Supplementary Information](#Supplementary_Information) for details).

# %% [markdown]
# ## Final Data Preprocessing
# <a id='Final_Data_Preprocessing'></a>
# The first consideration is to drop out some variables like `user_name`, `raw_timestamp_part_1`, `raw_timestamp_part_2`, `cvtd_timestamp`. These features describe experimental conditions but not are directly related to the performance of the exercises.

# %%
# Drop the variables "user_name", "raw_timestamp_part_1", "raw_timestamp_part_2", "cvtd_timestamp"
X_train.drop(columns=['user_name', 'raw_timestamp_part_1', 
                                 'raw_timestamp_part_2', 'cvtd_timestamp'],inplace=True)
X_train.head()
# Out:
#        roll_belt  pitch_belt  yaw_belt  gyros_belt_x  gyros_belt_y  \
# 36557  -1.021721    0.095449 -0.825405     -0.209831     -0.255327
# 13155  -1.415713   -0.151155 -0.824353     -0.738796     -2.162953
# 20336  -1.023316    0.132016 -0.814883      0.800011     -0.128152
# 17667  -1.017574    0.292554 -0.873806      0.126783     -0.255327
# 10556  -1.016936    0.140043 -0.823301     -0.065568     -0.509678
#
#        gyros_belt_z  roll_arm  pitch_arm   yaw_arm  gyros_arm_x  gyros_arm_y  \
# 36557      0.431051  1.736301  -0.033211 -1.449336     0.929049    -0.564726
# 13155     -0.709694  1.104827  -0.314106  0.447678     1.938186    -1.543598
# 20336      0.642300 -0.231036   0.134027  0.013120    -1.659387     2.242158
# 17667      0.346552  0.756760   0.617881  1.405935     0.762542    -0.352441
# 10556      0.431051  0.825548  -0.720024  0.627351     1.605171    -0.777012
#
#        gyros_arm_z  roll_dumbbell  pitch_dumbbell  yaw_dumbbell  \
# 36557    -0.261731      -0.370598        1.343279      1.417868
# 13155    -0.370819       0.408974        0.752048      1.210650
# 20336    -0.734445       0.864018       -0.712253     -0.729097
# 17667     0.120078       0.919606        0.595793      0.802698
# 10556     0.120078      -1.991131       -0.832407     -0.097306
#
#        gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 36557          0.190427         -0.848897         -0.387661
# 13155         -0.419198          0.883116          0.081152
# 20336         -0.158992          2.752318          0.155175
# 17667         -0.218468         -0.111505          0.219329
# 10556         -0.002869         -0.608816         -0.057024
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 36557          -0.052070           0.027569           2.451428     -1.959027
# 13155           0.182394           0.296593           2.365426     -1.949737
# 20336           0.229287           1.051697           0.122204      1.217852
# 17667          -0.576683           0.348564          -0.393809      0.948468
# 10556          -0.336357           0.039797           1.813579      1.282876
#
#        pitch_forearm  yaw_forearm  gyros_forearm_x  gyros_forearm_y  \
# 36557       0.020832     0.904494         0.021338        -0.289700
# 13155       0.244531    -0.050166        -0.215731        -0.999836
# 20336       0.965340    -1.624534        -0.036811        -1.004402
# 17667      -0.135757     0.736536        -0.086014        -0.024826
# 10556       0.180617     0.865883        -0.171001        -0.079627
#
#        gyros_forearm_z  accel_forearm_x  accel_forearm_y  magnet_forearm_x  \
# 36557        -0.075488        -0.044818         0.837878         -1.362467
# 13155        -0.665789         0.769019         0.496963          1.602314
# 20336        -1.274730        -0.006064        -0.706266         -0.391545
# 17667        -0.106557         1.062443         0.537071          0.322199
# 10556         0.110923        -0.022673         0.617286         -1.059054
#
#        magnet_forearm_y  magnet_forearm_z  num_window  total_accel_belt  \
# 36557          1.583112         -2.554679    1.500141         -1.216846
# 13155         -0.468220         -1.833000   -0.573307         -0.182295
# 20336         -1.302996         -0.229570    0.035819         -0.958208
# 17667          0.643495          0.030885   -0.186048         -1.087527
# 10556          1.523768         -2.505843   -0.795174         -1.087527
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 36557      0.054551     -1.100129      0.961073      -0.446507      -0.593657
# 13155     -0.751996     -1.274658      1.637464      -1.435389       1.785666
# 20336     -0.315116     -0.820883      1.130171      -0.183835       1.077534
# 17667     -0.382328     -0.925600      0.941179      -0.863692       0.114475
# 10556     -0.113480     -0.890694      0.990914      -0.307445      -0.565331
#
#        magnet_belt_z  total_accel_arm  accel_arm_x  accel_arm_y  accel_arm_z  \
# 36557      -1.361177         3.022254    -0.112801    -0.698711    -3.586379
# 13155       1.891069        -0.614785     0.228319     1.407412     0.418149
# 20336       0.698579         0.533754     0.778514    -0.051375    -1.666605
# 17667       0.543710         0.533754    -1.108654     0.960659     0.110685
# 10556      -1.314717        -0.901920     0.437394     1.106537     0.178177
#
#        magnet_arm_x  magnet_arm_y  magnet_arm_z  total_accel_dumbbell  \
# 36557     -0.942877     -1.801264     -2.502058             -0.758983
# 13155      1.040343     -0.409772     -0.141791             -0.369066
# 20336      0.923020     -1.741415     -2.025674              1.775478
# 17667     -1.064713      0.867009      0.724362             -1.051421
# 10556      0.895945     -0.614257      0.229418             -1.051421
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 36557          0.757798         -0.671753          0.845056
# 13155          0.668871         -0.065707          1.091091
# 20336         -1.287504          2.284264         -1.259911
# 17667          0.476198         -0.399651          0.507897
# 10556          0.253883         -0.993328          0.334761
#
#        total_accel_forearm  accel_forearm_z new_window
# 36557             0.530408         1.910597         no
# 13155            -0.361754         1.371799         no
# 20336            -1.253916        -1.111039         no
# 17667             0.332150        -1.205692         no
# 10556             0.133892         1.881473         no

# %% [markdown]
# Also, the variable `new_window` have two levels, so, in this case is feasible to use one hot encoding to encode this feature.

# %%
# Encode the "new_window" variable
X_train=pd.get_dummies(X_train,columns=['new_window'])
X_train.head()
# Out:
#        roll_belt  pitch_belt  yaw_belt  gyros_belt_x  gyros_belt_y  \
# 36557  -1.021721    0.095449 -0.825405     -0.209831     -0.255327
# 13155  -1.415713   -0.151155 -0.824353     -0.738796     -2.162953
# 20336  -1.023316    0.132016 -0.814883      0.800011     -0.128152
# 17667  -1.017574    0.292554 -0.873806      0.126783     -0.255327
# 10556  -1.016936    0.140043 -0.823301     -0.065568     -0.509678
#
#        gyros_belt_z  roll_arm  pitch_arm   yaw_arm  gyros_arm_x  gyros_arm_y  \
# 36557      0.431051  1.736301  -0.033211 -1.449336     0.929049    -0.564726
# 13155     -0.709694  1.104827  -0.314106  0.447678     1.938186    -1.543598
# 20336      0.642300 -0.231036   0.134027  0.013120    -1.659387     2.242158
# 17667      0.346552  0.756760   0.617881  1.405935     0.762542    -0.352441
# 10556      0.431051  0.825548  -0.720024  0.627351     1.605171    -0.777012
#
#        gyros_arm_z  roll_dumbbell  pitch_dumbbell  yaw_dumbbell  \
# 36557    -0.261731      -0.370598        1.343279      1.417868
# 13155    -0.370819       0.408974        0.752048      1.210650
# 20336    -0.734445       0.864018       -0.712253     -0.729097
# 17667     0.120078       0.919606        0.595793      0.802698
# 10556     0.120078      -1.991131       -0.832407     -0.097306
#
#        gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 36557          0.190427         -0.848897         -0.387661
# 13155         -0.419198          0.883116          0.081152
# 20336         -0.158992          2.752318          0.155175
# 17667         -0.218468         -0.111505          0.219329
# 10556         -0.002869         -0.608816         -0.057024
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 36557          -0.052070           0.027569           2.451428     -1.959027
# 13155           0.182394           0.296593           2.365426     -1.949737
# 20336           0.229287           1.051697           0.122204      1.217852
# 17667          -0.576683           0.348564          -0.393809      0.948468
# 10556          -0.336357           0.039797           1.813579      1.282876
#
#        pitch_forearm  yaw_forearm  gyros_forearm_x  gyros_forearm_y  \
# 36557       0.020832     0.904494         0.021338        -0.289700
# 13155       0.244531    -0.050166        -0.215731        -0.999836
# 20336       0.965340    -1.624534        -0.036811        -1.004402
# 17667      -0.135757     0.736536        -0.086014        -0.024826
# 10556       0.180617     0.865883        -0.171001        -0.079627
#
#        gyros_forearm_z  accel_forearm_x  accel_forearm_y  magnet_forearm_x  \
# 36557        -0.075488        -0.044818         0.837878         -1.362467
# 13155        -0.665789         0.769019         0.496963          1.602314
# 20336        -1.274730        -0.006064        -0.706266         -0.391545
# 17667        -0.106557         1.062443         0.537071          0.322199
# 10556         0.110923        -0.022673         0.617286         -1.059054
#
#        magnet_forearm_y  magnet_forearm_z  num_window  total_accel_belt  \
# 36557          1.583112         -2.554679    1.500141         -1.216846
# 13155         -0.468220         -1.833000   -0.573307         -0.182295
# 20336         -1.302996         -0.229570    0.035819         -0.958208
# 17667          0.643495          0.030885   -0.186048         -1.087527
# 10556          1.523768         -2.505843   -0.795174         -1.087527
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 36557      0.054551     -1.100129      0.961073      -0.446507      -0.593657
# 13155     -0.751996     -1.274658      1.637464      -1.435389       1.785666
# 20336     -0.315116     -0.820883      1.130171      -0.183835       1.077534
# 17667     -0.382328     -0.925600      0.941179      -0.863692       0.114475
# 10556     -0.113480     -0.890694      0.990914      -0.307445      -0.565331
#
#        magnet_belt_z  total_accel_arm  accel_arm_x  accel_arm_y  accel_arm_z  \
# 36557      -1.361177         3.022254    -0.112801    -0.698711    -3.586379
# 13155       1.891069        -0.614785     0.228319     1.407412     0.418149
# 20336       0.698579         0.533754     0.778514    -0.051375    -1.666605
# 17667       0.543710         0.533754    -1.108654     0.960659     0.110685
# 10556      -1.314717        -0.901920     0.437394     1.106537     0.178177
#
#        magnet_arm_x  magnet_arm_y  magnet_arm_z  total_accel_dumbbell  \
# 36557     -0.942877     -1.801264     -2.502058             -0.758983
# 13155      1.040343     -0.409772     -0.141791             -0.369066
# 20336      0.923020     -1.741415     -2.025674              1.775478
# 17667     -1.064713      0.867009      0.724362             -1.051421
# 10556      0.895945     -0.614257      0.229418             -1.051421
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 36557          0.757798         -0.671753          0.845056
# 13155          0.668871         -0.065707          1.091091
# 20336         -1.287504          2.284264         -1.259911
# 17667          0.476198         -0.399651          0.507897
# 10556          0.253883         -0.993328          0.334761
#
#        total_accel_forearm  accel_forearm_z  new_window_no  new_window_yes
# 36557             0.530408         1.910597              1               0
# 13155            -0.361754         1.371799              1               0
# 20336            -1.253916        -1.111039              1               0
# 17667             0.332150        -1.205692              1               0
# 10556             0.133892         1.881473              1               0

# %% [markdown]
# ### Transform Validation Data
# Before going ahead with the feature selection analysis, let's transform the validation data using all the previously implemented steps. All these functions are included in the file "functions.py".

# %%
# Transform the data types
X_val = types_features(X_val)
# Drop the columns with more than 40% of missing data
X_val.drop(columns=columns_out,inplace=True)
# Impute NaN with the median
X_val[dictionary['float']]=imputer.transform(X_val[dictionary['float']])
# Standarize the data
X_val = standardizer_data(X_val,type_var,scaler)
# Drop the variables "user_name", "raw_timestamp_part_1", "raw_timestamp_part_2", "cvtd_timestamp"
X_val.drop(columns=['user_name', 'raw_timestamp_part_1',
                    'raw_timestamp_part_2', 'cvtd_timestamp'],inplace=True)
# Encode the "new_window" variable
X_val=pd.get_dummies(X_val,columns=['new_window'])
print('The validation dataset has {} features and {} observations, while the train dataset has {} \
features and {} observations'.format(X_val.shape[0],X_val.shape[1],
                                      X_train.shape[0],X_train.shape[1]))
# Out:
# The validation dataset has 6279 features and 55 observations, while the train dataset has 25112 features and 55 observations

# %%
# Print the head of the validation dataset 
X_val.head()
# Out:
#        roll_belt  pitch_belt  yaw_belt  gyros_belt_x  gyros_belt_y  \
# 18224  -1.018371    0.074936 -0.809622     -0.113655     -0.509678
# 25166   1.002475   -1.836801  1.805073      0.415310      0.889248
# 20301  -1.030494    0.222987 -0.814883      0.415310     -0.128152
# 16879  -1.014862    0.312175 -0.867493      0.030608     -0.509678
# 26756   1.433155   -1.622750  1.542025     -0.642621      1.779473
#
#        gyros_belt_z  roll_arm  pitch_arm   yaw_arm  gyros_arm_x  gyros_arm_y  \
# 18224      0.346552  1.708786  -0.681056 -0.945137     0.671719    -0.222711
# 25166     -0.287196 -0.221681  -0.333590 -0.718108    -0.917671     0.308002
# 20301      0.684550 -0.231036   0.134027  0.013120    -0.054859     0.272621
# 16879      0.473301  0.793906  -0.960327  0.837666    -2.471742     1.558127
# 26756      1.191548 -1.183062  -1.794894  0.462999     0.363933    -0.470377
#
#        gyros_arm_z  roll_dumbbell  pitch_dumbbell  yaw_dumbbell  \
# 18224    -0.498088       0.711140        1.509573      0.763996
# 25166     0.629155       0.382426       -0.585948     -1.164688
# 20301    -0.552632       0.460841       -1.246683     -0.874025
# 16879    -1.898051      -1.841361       -0.079574      0.596113
# 26756     0.956419       0.641618       -0.375234     -1.009689
#
#        gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 18224         -0.359723          0.094279          0.041673
# 25166         -0.047475         -0.111505         -0.071829
# 20301          0.748012         -1.209018         -0.466619
# 16879         -0.121820         -0.265843         -0.007675
# 26756         -0.017737          0.917413          0.120631
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 18224           0.583913           0.550333           2.329592      1.282876
# 25166          -0.682192           0.122339           0.064869     -0.314853
# 20301          -0.559098           0.290479           0.358709      0.957757
# 16879          -0.723223           0.082596          -0.300640      1.087804
# 26756          -0.456520           0.476962           0.057702     -0.314853
#
#        pitch_forearm  yaw_forearm  gyros_forearm_x  gyros_forearm_y  \
# 18224       0.301344    -0.934360        -0.551206         0.696728
# 25166      -0.394609    -0.186270         0.307610        -0.186947
# 20301      -0.698201     0.520313        -0.564625         0.452404
# 16879      -0.452487     0.827272        -0.001027        -0.029392
# 26756      -0.394609    -0.186270         0.325502         0.434137
#
#        gyros_forearm_z  accel_forearm_x  accel_forearm_y  magnet_forearm_x  \
# 18224         0.657727         0.780091        -1.147450          1.847934
# 25166        -0.218403        -0.880801         0.832865         -1.053275
# 20301         0.458889         1.710191         0.867959          0.686295
# 16879        -0.081702         1.007080         0.527044          0.382882
# 26756         0.129564        -1.805364        -0.004382         -0.969475
#
#        magnet_forearm_y  magnet_forearm_z  num_window  total_accel_belt  \
# 18224         -2.282176         -0.877996   -0.141675         -1.087527
# 25166          0.358643          0.649467    0.463417          0.852257
# 20301          0.651408          1.257197    0.035819         -0.828889
# 16879          0.639539          0.071582   -0.258659         -1.087527
# 26756         -0.677903          0.155687    0.612673          1.628170
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 18224     -0.046268     -0.855789      0.990914      -0.245640      -0.706958
# 25166      1.802067      0.540444     -0.889054       1.747576       0.199451
# 20301     -0.214298     -1.169941      1.160012      -0.122030       1.020884
# 16879     -0.382328     -0.925600      0.921285      -0.770984       0.142800
# 26756      2.440583      0.505538     -1.436135       1.685771      -2.009920
#
#        magnet_belt_z  total_accel_arm  accel_arm_x  accel_arm_y  accel_arm_z  \
# 18224      -1.144361         2.160850     0.850040    -0.306662    -2.911458
# 25166       0.357867        -1.284766    -0.134809    -0.862825     0.800604
# 20301       0.574684         0.916600    -1.048133     1.361825    -0.489244
# 16879       0.466275        -0.901920    -0.266856     0.741841     0.673119
# 26756      -1.670915         0.246619     1.180157    -1.364283    -0.916694
#
#        magnet_arm_x  magnet_arm_y  magnet_arm_z  total_accel_dumbbell  \
# 18224      0.336402     -1.896025     -2.514432              0.410768
# 25166      0.591355     -0.315011      0.557319              0.313289
# 20301     -1.152705      1.420613      0.319126              1.775478
# 16879      0.740266     -0.649169      0.452143             -1.051421
# 26756      1.245660     -1.182823     -1.527636              0.508248
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 18224          1.587775          0.837176          1.337126
# 25166         -0.368601          0.354814         -0.895414
# 20301         -2.087840          1.418485         -1.515058
# 16879          0.372451         -0.968591          0.480559
# 26756         -0.250032          0.812440         -0.895414
#
#        total_accel_forearm  accel_forearm_z  new_window_no  new_window_yes
# 18224            -1.253916         1.779538              1               0
# 25166             0.629537         0.454387              1               0
# 20301             0.926925        -0.426620              1               0
# 16879             0.431279        -1.416843              0               1
# 26756             0.827796         0.483511              1               0

# %% [markdown]
# ## Feature Selection/Importance
# <a id='Feature_Selection_Importance'></a>

# %% [markdown]
# Now is the moment to compute the feature importance in our dataset! There are three main classes of methods to feature selection:
# 1. Univariate: Uses hypothesis statistical tests to compute the relationship between each feature and the target.
# 2. Model-Base: Use supervised machine learning algorithms to evaluate the importance of each feature. Some classic examples for this alternative are the Lasso Regression and tree-based models.
# 3. Iterative: Use a series of models considering different amounts of features (increasing by one or reducing by one).
#
# In my experience, a really nice and powerful alternative is to use Random Forest with two objectives. The first one is for feature selection and the second one is for our classification task. Random Forest is an ensemble method that doesn't need feature normalization and works well using a mixture of features types like continuous and binary variables.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Set and fit the model
rfc_fs=RandomForestClassifier(random_state=1)
rfc_fs.fit(X_train,y_train);
# Extract the names of the features
features = X_train.columns
#  Extract the importance of the features from the RF
importance=rfc_fs.feature_importances_
# Compute the accuracy in the training and validation dataset
acc_train=accuracy_score(rfc_fs.predict(X_train),y_train)
acc_val=accuracy_score(rfc_fs.predict(X_val),y_val)
print('With this vanilla Randon Forest model we obtain an accuracy in the training data of {}.\n \
On the other hand, the accuracy in the validation data is {}.'.format(acc_train,acc_val))
# Out:
# With this vanilla Randon Forest model we obtain an accuracy in the training data of 1.0.
#  On the other hand, the accuracy in the validation data is 0.999362955884695.

# %%
# Index of the features with importance different to zero
index=importance != 0
# Extract the most important features (mi)
features_mi=features[index]
importance_mi=importance[index]

## Plot the features importance for those features with importance different to zero
# Sort the values in descending order
indices = np.argsort(importance_mi)
# plot the results
plt.figure(figsize=(10,12))
plt.title('Feature Importance')
plt.barh(range(len(indices)), importance_mi[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features_mi[i] for i in indices])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# The abovee results reveals two inportant points to take into account:
# 1. This dataset doesn't seem to be a complicated one because even with a vanilla Random Forest model, we obtain an accuracy close to 1 in the validation dataset.
# 2. Except for the variables `new_window_no` and `new_window_yes`, all the other features seem to be important for the model.

# %%
# Drop the variables "new_window_no" and "new_window_yes" from the  training and testing dataset
X_train.drop(columns=['new_window_no','new_window_yes'],inplace=True)
X_val.drop(columns=['new_window_no','new_window_yes'],inplace=True)

# %% [markdown]
# ## Classification Model
# <a id='Classification_Model'></a>
# At this point, our data is ready to be used as an input in a machine learning algorithm. Also, we know that this classification problem is very simple, and even with a vanilla Random Forest model, we obtained almost perfect accuracy. Given, this situation, I am going to test 3 differents machine learning approaches:
# 1. Logistic Regression (linear approach).
# 2. SVM (nonlinear approach).
# 3. Random Forest (nonlinear approach).

# %% [markdown]
# ### Logistic Regression
# This is a classical binary classification algorithm that it's extended to multiclass problems considering each class against the rest of the classes. The main parameter in this model is the regularization parameter C, which is the inverse of the regularization parameter in the classical linear regression.
# * Higher C correspond to less regularization (the model will try to fit the data as well as possible, possible overfitting).
# * Lower C corresponds to more regularization (the model puts more emphasis on finding a coefficient vector close to zero).

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
# Set the parameters
parameter={'C':[0.1,0.5,1,5,10]}
# Set the model
clf_lr=LogisticRegression(max_iter=1000,random_state=1)
# Gridsearch
clf_lr_gs=GridSearchCV(clf_lr,parameter)
clf_lr_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=1000, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=1, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 0.5, 1, 5, 10]}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
print('Best Parameter: {}\n\
Accuracy Training: {}\n\
Accuracy Validation: {}'.format(clf_lr_gs.best_params_,accuracy_score(clf_lr_gs.predict(X_train),y_train),
                                      accuracy_score(clf_lr_gs.predict(X_val),y_val)))
# Out:
# Best Parameter: {'C': 5}
# Accuracy Training: 0.7524689391525964
# Accuracy Validation: 0.7466157031374423

# %% [markdown]
# ### SVM
# It is defined as the maximun width the decision boundary area can be increase before hitting a data point.
# The main parameters are:
# * Kernel: The kernel used for the kernalized version of SVM. Some examples are "Linear Kernel" (Default), "Polinomial Kernel" (poly), "rbf", and customized kernels.
# * C: Control the tradeoff between smooth decision boundary and classifying training points correctly. It's the inverse of the $\alpha$ parameter in linear regression models.
#     * Large C generate less regularization in the model and as consequence the model is going to fit more the training data (case possible overfitting).
#     * Small C generate more regularization and this leads the model to fit the training data as best as it can, but the model could has more generalization power (take care with the underfitting).
# * Gamma ($\gamma$): Defines how the influence of a single training example reaches. For low values of $\gamma$, we are considering more far points in the training data, while for hight values we only are taking into account points close to the decision boundary.

# %%
from sklearn.svm import SVC
# Parameters space
parameters={'C':[0.1,0.5,1,5,10], 'kernel':['linear', 'poly', 'rbf']}
# Create the model
clf_svm = SVC(random_state=1)
# Set the Grid Search
clf_svm_gs = GridSearchCV(clf_svm,parameter)
clf_svm_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=1, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 0.5, 1, 5, 10]}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
print('Best Parameter: {}\n\
Accuracy Training: {}\n\
Accuracy Validation: {}'.format(clf_svm_gs.best_params_,accuracy_score(clf_svm_gs.predict(X_train),y_train),
                                      accuracy_score(clf_svm_gs.predict(X_val),y_val)))
# Out:
# Best Parameter: {'C': 10}
# Accuracy Training: 0.9951019432940427
# Accuracy Validation: 0.9928332537028189

# %% [markdown]
# ### Random Forest
# This bagging ML algorithm is well known because of its versatility and good performance in a wild range of problems. It's important to remember that the key parameters of this ML algorithm are:
# * n_estimators: number of trees to use in the ensemble.
# * max_features: max number of features considered for splitting a node. This parameter influences the diversity of the trees. Normally, people select $\sqrt{n}$ to set this parameter (n is the number of features).
# * max_depth: Maximum depth of the tree.

# %%
from sklearn.ensemble import RandomForestClassifier
# Parametric space
parameters={'n_estimators': [20,50,100,150],
           'max_features': [2,3,4,8,10,'auto'],
           'max_depth': [2,4,6,8,10,None]}
# Set the Random Forest Model
clf_rf = RandomForestClassifier(random_state=1)
# Set the grid search model
clf_rf_gs = GridSearchCV(clf_rf, parameters,n_jobs=-1)
# Fit the model
clf_rf_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': [2, 4, 6, 8, 10, None],
#                          'max_features': [2, 3, 4, 8, 10, 'auto'],
#                          'n_estimators': [20, 50, 100, 150]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('Best Parameter: {}\n\
Accuracy Training: {}\n\
Accuracy Validation: {}'.format(clf_rf_gs.best_params_,accuracy_score(clf_rf_gs.predict(X_train),y_train),
                                      accuracy_score(clf_rf_gs.predict(X_val),y_val)))
# Out:
# Best Parameter: {'max_depth': None, 'max_features': 10, 'n_estimators': 100}
# Accuracy Training: 1.0
# Accuracy Validation: 0.999362955884695

# %% [markdown]
# In the three used approaches, I use a grid search for parameter tuning. The results of the Logistic Regression reveals a poor accuracy in comparison with the results obtained by SVM and Random Forest. This fact could be because the relationship between the independent and dependent variables isn't linear.
# As was advertised previously, this classification problem is not very complicated, and for that reason was possible to obtain almost an accuracy of 1 for both models in the training and validation dataset. Both alternatives are eficient in high dimmensional spaces, but SVM is less suitable for large datasets.

# %% [markdown]
# ## Test Data
# Finally, it's time to evaluate the performance of our ML algorithms in the case of the testing dataset. First, I am going to use the function "preprocess_data" available in "functions.py" to prepare the data in accordance with all the preprocessing steps explained previously.

# %%
# Original testing dataset
X_test.head()
# Out:
#       user_name  raw_timestamp_part_1  raw_timestamp_part_2    cvtd_timestamp  \
# 26438    adelmo            1322832910                324344  02/12/2011 13:35
# 24627    adelmo            1322832856                864317  02/12/2011 13:34
# 29014    adelmo            1322832832                120541  02/12/2011 13:33
# 15843  carlitos            1323084268                124289  05/12/2011 11:24
# 26577    adelmo            1322832914                532299  02/12/2011 13:35
#
#       new_window  num_window  roll_belt  pitch_belt  yaw_belt  \
# 26438         no         578     124.00      -42.00     166.0
# 24627         no         536     124.00      -44.30     173.0
# 29014         no         638     125.00      -43.70     167.0
# 15843         no         350       1.54        5.46     -92.7
# 26577         no         581     119.00      -46.40     172.0
#
#        total_accel_belt kurtosis_roll_belt kurtosis_picth_belt  \
# 26438                17                NaN                 NaN
# 24627                17                NaN                 NaN
# 29014                18                NaN                 NaN
# 15843                 3                NaN                 NaN
# 26577                17                NaN                 NaN
#
#       kurtosis_yaw_belt skewness_roll_belt skewness_roll_belt.1  \
# 26438               NaN                NaN                  NaN
# 24627               NaN                NaN                  NaN
# 29014               NaN                NaN                  NaN
# 15843               NaN                NaN                  NaN
# 26577               NaN                NaN                  NaN
#
#       skewness_yaw_belt  max_roll_belt  max_picth_belt max_yaw_belt  \
# 26438               NaN            NaN             NaN          NaN
# 24627               NaN            NaN             NaN          NaN
# 29014               NaN            NaN             NaN          NaN
# 15843               NaN            NaN             NaN          NaN
# 26577               NaN            NaN             NaN          NaN
#
#        min_roll_belt  min_pitch_belt min_yaw_belt  amplitude_roll_belt  \
# 26438            NaN             NaN          NaN                  NaN
# 24627            NaN             NaN          NaN                  NaN
# 29014            NaN             NaN          NaN                  NaN
# 15843            NaN             NaN          NaN                  NaN
# 26577            NaN             NaN          NaN                  NaN
#
#        amplitude_pitch_belt amplitude_yaw_belt  var_total_accel_belt  \
# 26438                   NaN                NaN                   NaN
# 24627                   NaN                NaN                   NaN
# 29014                   NaN                NaN                   NaN
# 15843                   NaN                NaN                   NaN
# 26577                   NaN                NaN                   NaN
#
#        avg_roll_belt  stddev_roll_belt  var_roll_belt  avg_pitch_belt  \
# 26438            NaN               NaN            NaN             NaN
# 24627            NaN               NaN            NaN             NaN
# 29014            NaN               NaN            NaN             NaN
# 15843            NaN               NaN            NaN             NaN
# 26577            NaN               NaN            NaN             NaN
#
#        stddev_pitch_belt  var_pitch_belt  avg_yaw_belt  stddev_yaw_belt  \
# 26438                NaN             NaN           NaN              NaN
# 24627                NaN             NaN           NaN              NaN
# 29014                NaN             NaN           NaN              NaN
# 15843                NaN             NaN           NaN              NaN
# 26577                NaN             NaN           NaN              NaN
#
#        var_yaw_belt  gyros_belt_x  gyros_belt_y  gyros_belt_z  accel_belt_x  \
# 26438           NaN          0.08          0.11         -0.16            50
# 24627           NaN         -0.22          0.14         -0.34            54
# 29014           NaN          0.11          0.11         -0.16            48
# 15843           NaN         -0.03          0.00         -0.07           -17
# 26577           NaN          0.16          0.10         -0.25            54
#
#        accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 26438            42          -158            162            610
# 24627            41          -157            184            606
# 29014            46          -161            167            613
# 15843             6            27              3            611
# 26577            41          -154            183            614
#
#        magnet_belt_z  roll_arm  pitch_arm  yaw_arm  total_accel_arm  \
# 26438           -292     -8.12      -5.07    -49.0               15
# 24627           -327     14.80      21.20    -33.7               15
# 29014           -317     71.90      58.70     40.2               25
# 15843           -302     70.10      10.10     96.7               31
# 26577           -262    -13.40     -11.80    -43.0                9
#
#        var_accel_arm  avg_roll_arm  stddev_roll_arm  var_roll_arm  \
# 26438            NaN           NaN              NaN           NaN
# 24627            NaN           NaN              NaN           NaN
# 29014            NaN           NaN              NaN           NaN
# 15843            NaN           NaN              NaN           NaN
# 26577            NaN           NaN              NaN           NaN
#
#        avg_pitch_arm  stddev_pitch_arm  var_pitch_arm  avg_yaw_arm  \
# 26438            NaN               NaN            NaN          NaN
# 24627            NaN               NaN            NaN          NaN
# 29014            NaN               NaN            NaN          NaN
# 15843            NaN               NaN            NaN          NaN
# 26577            NaN               NaN            NaN          NaN
#
#        stddev_yaw_arm  var_yaw_arm  gyros_arm_x  gyros_arm_y  gyros_arm_z  \
# 26438             NaN          NaN        -0.83        -0.22         0.87
# 24627             NaN          NaN        -3.15         0.56         0.64
# 29014             NaN          NaN         0.66        -0.69         0.89
# 15843             NaN          NaN         1.51        -0.82         0.52
# 26577             NaN          NaN         0.87        -0.58         0.49
#
#        accel_arm_x  accel_arm_y  accel_arm_z  magnet_arm_x  magnet_arm_y  \
# 26438          -81          -44          120           263           155
# 24627         -120          -26           85           310           232
# 29014         -242          -26           -1          -193           331
# 15843         -267          143          -54          -215           341
# 26577          -41          -43           68           382           163
#
#        magnet_arm_z kurtosis_roll_arm kurtosis_picth_arm kurtosis_yaw_arm  \
# 26438           587               NaN                NaN              NaN
# 24627           527               NaN                NaN              NaN
# 29014           581               NaN                NaN              NaN
# 15843           552               NaN                NaN              NaN
# 26577           534               NaN                NaN              NaN
#
#       skewness_roll_arm skewness_pitch_arm skewness_yaw_arm  max_roll_arm  \
# 26438               NaN                NaN              NaN           NaN
# 24627               NaN                NaN              NaN           NaN
# 29014               NaN                NaN              NaN           NaN
# 15843               NaN                NaN              NaN           NaN
# 26577               NaN                NaN              NaN           NaN
#
#        max_picth_arm  max_yaw_arm  min_roll_arm  min_pitch_arm  min_yaw_arm  \
# 26438            NaN          NaN           NaN            NaN          NaN
# 24627            NaN          NaN           NaN            NaN          NaN
# 29014            NaN          NaN           NaN            NaN          NaN
# 15843            NaN          NaN           NaN            NaN          NaN
# 26577            NaN          NaN           NaN            NaN          NaN
#
#        amplitude_roll_arm  amplitude_pitch_arm  amplitude_yaw_arm  \
# 26438                 NaN                  NaN                NaN
# 24627                 NaN                  NaN                NaN
# 29014                 NaN                  NaN                NaN
# 15843                 NaN                  NaN                NaN
# 26577                 NaN                  NaN                NaN
#
#        roll_dumbbell  pitch_dumbbell  yaw_dumbbell kurtosis_roll_dumbbell  \
# 26438      60.310497      -30.647880    -87.310375                    NaN
# 24627      52.981705      -24.332893    -97.656791                    NaN
# 29014      98.676381       -4.418033    -58.191033                    NaN
# 15843      94.035322        4.897511     62.792453                    NaN
# 26577      63.584414      -25.906158    -86.747538                    NaN
#
#       kurtosis_picth_dumbbell kurtosis_yaw_dumbbell skewness_roll_dumbbell  \
# 26438                     NaN                   NaN                    NaN
# 24627                     NaN                   NaN                    NaN
# 29014                     NaN                   NaN                    NaN
# 15843                     NaN                   NaN                    NaN
# 26577                     NaN                   NaN                    NaN
#
#       skewness_pitch_dumbbell skewness_yaw_dumbbell  max_roll_dumbbell  \
# 26438                     NaN                   NaN                NaN
# 24627                     NaN                   NaN                NaN
# 29014                     NaN                   NaN                NaN
# 15843                     NaN                   NaN                NaN
# 26577                     NaN                   NaN                NaN
#
#        max_picth_dumbbell max_yaw_dumbbell  min_roll_dumbbell  \
# 26438                 NaN              NaN                NaN
# 24627                 NaN              NaN                NaN
# 29014                 NaN              NaN                NaN
# 15843                 NaN              NaN                NaN
# 26577                 NaN              NaN                NaN
#
#        min_pitch_dumbbell min_yaw_dumbbell  amplitude_roll_dumbbell  \
# 26438                 NaN              NaN                      NaN
# 24627                 NaN              NaN                      NaN
# 29014                 NaN              NaN                      NaN
# 15843                 NaN              NaN                      NaN
# 26577                 NaN              NaN                      NaN
#
#        amplitude_pitch_dumbbell amplitude_yaw_dumbbell  total_accel_dumbbell  \
# 26438                       NaN                    NaN                    17
# 24627                       NaN                    NaN                    17
# 29014                       NaN                    NaN                    21
# 15843                       NaN                    NaN                     4
# 26577                       NaN                    NaN                    18
#
#        var_accel_dumbbell  avg_roll_dumbbell  stddev_roll_dumbbell  \
# 26438                 NaN                NaN                   NaN
# 24627                 NaN                NaN                   NaN
# 29014                 NaN                NaN                   NaN
# 15843                 NaN                NaN                   NaN
# 26577                 NaN                NaN                   NaN
#
#        var_roll_dumbbell  avg_pitch_dumbbell  stddev_pitch_dumbbell  \
# 26438                NaN                 NaN                    NaN
# 24627                NaN                 NaN                    NaN
# 29014                NaN                 NaN                    NaN
# 15843                NaN                 NaN                    NaN
# 26577                NaN                 NaN                    NaN
#
#        var_pitch_dumbbell  avg_yaw_dumbbell  stddev_yaw_dumbbell  \
# 26438                 NaN               NaN                  NaN
# 24627                 NaN               NaN                  NaN
# 29014                 NaN               NaN                  NaN
# 15843                 NaN               NaN                  NaN
# 26577                 NaN               NaN                  NaN
#
#        var_yaw_dumbbell  gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 26438               NaN              0.19              0.08              0.03
# 24627               NaN              0.27              0.02              0.00
# 29014               NaN             -0.11              0.59              0.10
# 15843               NaN              0.26              0.10              0.00
# 26577               NaN              0.16             -0.11             -0.08
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 26438               -50                94              -127
# 24627               -41                86              -141
# 29014                -9               170              -112
# 15843                 2                33                24
# 26577               -44               102              -131
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 26438             -539.0              296.0               60.0           0.0
# 24627             -545.0              272.0               71.0           0.0
# 29014             -294.0              528.0               96.0           0.0
# 15843             -573.0              261.0              -36.0         114.0
# 26577             -518.0              326.0               70.0           0.0
#
#        pitch_forearm  yaw_forearm kurtosis_roll_forearm  \
# 26438            0.0          0.0                   NaN
# 24627            0.0          0.0                   NaN
# 29014            0.0          0.0                   NaN
# 15843          -35.2        112.0                   NaN
# 26577            0.0          0.0                   NaN
#
#       kurtosis_picth_forearm kurtosis_yaw_forearm skewness_roll_forearm  \
# 26438                    NaN                  NaN                   NaN
# 24627                    NaN                  NaN                   NaN
# 29014                    NaN                  NaN                   NaN
# 15843                    NaN                  NaN                   NaN
# 26577                    NaN                  NaN                   NaN
#
#       skewness_pitch_forearm skewness_yaw_forearm  max_roll_forearm  \
# 26438                    NaN                  NaN               NaN
# 24627                    NaN                  NaN               NaN
# 29014                    NaN                  NaN               NaN
# 15843                    NaN                  NaN               NaN
# 26577                    NaN                  NaN               NaN
#
#        max_picth_forearm max_yaw_forearm  min_roll_forearm  min_pitch_forearm  \
# 26438                NaN             NaN               NaN                NaN
# 24627                NaN             NaN               NaN                NaN
# 29014                NaN             NaN               NaN                NaN
# 15843                NaN             NaN               NaN                NaN
# 26577                NaN             NaN               NaN                NaN
#
#       min_yaw_forearm  amplitude_roll_forearm  amplitude_pitch_forearm  \
# 26438             NaN                     NaN                      NaN
# 24627             NaN                     NaN                      NaN
# 29014             NaN                     NaN                      NaN
# 15843             NaN                     NaN                      NaN
# 26577             NaN                     NaN                      NaN
#
#       amplitude_yaw_forearm  total_accel_forearm  var_accel_forearm  \
# 26438                   NaN                   42                NaN
# 24627                   NaN                   32                NaN
# 29014                   NaN                   51                NaN
# 15843                   NaN                   41                NaN
# 26577                   NaN                   54                NaN
#
#        avg_roll_forearm  stddev_roll_forearm  var_roll_forearm  \
# 26438               NaN                  NaN               NaN
# 24627               NaN                  NaN               NaN
# 29014               NaN                  NaN               NaN
# 15843               NaN                  NaN               NaN
# 26577               NaN                  NaN               NaN
#
#        avg_pitch_forearm  stddev_pitch_forearm  var_pitch_forearm  \
# 26438                NaN                   NaN                NaN
# 24627                NaN                   NaN                NaN
# 29014                NaN                   NaN                NaN
# 15843                NaN                   NaN                NaN
# 26577                NaN                   NaN                NaN
#
#        avg_yaw_forearm  stddev_yaw_forearm  var_yaw_forearm  gyros_forearm_x  \
# 26438              NaN                 NaN              NaN             0.93
# 24627              NaN                 NaN              NaN             0.83
# 29014              NaN                 NaN              NaN             0.51
# 15843              NaN                 NaN              NaN             0.63
# 26577              NaN                 NaN              NaN             1.09
#
#        gyros_forearm_y  gyros_forearm_z  accel_forearm_x  accel_forearm_y  \
# 26438            -0.96             0.03           -331.0            250.0
# 24627             1.65             0.46           -310.0             -7.0
# 29014             2.68             1.31           -146.0            478.0
# 15843            -0.11             0.62            102.0            315.0
# 26577             1.17             0.52           -184.0            489.0
#
#        accel_forearm_z  magnet_forearm_x  magnet_forearm_y  magnet_forearm_z
# 26438               -3            -698.0             249.0             531.0
# 24627              -17            -266.0            -501.0             152.0
# 29014               53            -583.0             751.0             888.0
# 15843             -236             -93.0             678.0             371.0
# 26577              -50            -459.0             744.0             516.0

# %%
# Preprocess the testing dataset using the function "preprocess_data"
from functions import preprocess_data
X_test_final=preprocess_data(X_test,columns_out,type_var,imputer,scaler)
X_test_final.head()
# Out:
#        roll_belt  pitch_belt  yaw_belt  gyros_belt_x  gyros_belt_y  \
# 26438   0.938670   -1.890313  1.857682      0.415310      0.889248
# 24627   0.938670   -1.992879  1.931336     -1.027322      1.270773
# 29014   0.954621   -1.966123  1.868204      0.559573      0.889248
# 15843  -1.014702    0.226109 -0.864336     -0.113655     -0.509678
# 26577   0.858915   -2.086526  1.920814      0.800011      0.762073
#
#        gyros_belt_z  roll_arm  pitch_arm   yaw_arm  gyros_arm_x  gyros_arm_y  \
# 26438     -0.118197 -0.342748  -0.030613 -0.669360    -0.443377     0.048542
# 24627     -0.878694 -0.027423   0.822464 -0.456259    -1.613975     0.968446
# 29014     -0.118197  0.758136   2.040217  0.573031     0.308430    -0.505758
# 15843      0.262052  0.733372   0.462009  1.359972     0.737313    -0.659075
# 26577     -0.498445 -0.415388  -0.249159 -0.585791     0.414389    -0.376028
#
#        gyros_arm_z  roll_dumbbell  pitch_dumbbell  yaw_dumbbell  \
# 26438     1.083689       0.518658       -0.532770     -1.072811
# 24627     0.665518       0.413586       -0.361887     -1.198109
# 29014     1.120052       1.068710        0.177007     -0.720167
# 15843     0.447342       1.002171        0.429085      0.744978
# 26577     0.392798       0.565597       -0.404459     -1.065994
#
#        gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 26438          0.019435          0.059981          0.081152
# 24627          0.078911         -0.042911          0.066348
# 29014         -0.203599          0.934562          0.115696
# 15843          0.071476          0.094279          0.066348
# 26577         -0.002869         -0.265843          0.026869
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 26438          -0.620645           0.229337           0.107870     -0.314853
# 24627          -0.638230           0.155967           0.186705     -0.314853
# 29014           0.097401           0.938584           0.365876     -0.314853
# 15843          -0.720292           0.122339          -0.580147      0.744107
# 26577          -0.559098           0.321050           0.179538     -0.314853
#
#        pitch_forearm  yaw_forearm  gyros_forearm_x  gyros_forearm_y  \
# 26438      -0.394609    -0.186270         0.352340        -0.244032
# 24627      -0.394609    -0.186270         0.307610         0.351935
# 29014      -0.394609    -0.186270         0.164474         0.587125
# 15843      -1.644484     0.894841         0.218150        -0.049943
# 26577      -0.394609    -0.186270         0.423908         0.242332
#
#        gyros_forearm_z  accel_forearm_x  accel_forearm_y  magnet_forearm_x  \
# 26438        -0.075488        -1.473186         0.436802         -1.096619
# 24627         0.191700        -1.356923        -0.851657          0.151710
# 29014         0.719864        -0.448969         1.579870         -0.764310
# 15843         0.291120         0.924035         0.762677          0.651619
# 26577         0.228983        -0.659349         1.635018         -0.405993
#
#        magnet_forearm_y  magnet_forearm_z  num_window  total_accel_belt  \
# 26438         -0.258537          0.367307    0.580401          0.722938
# 24627         -1.742143         -0.660950    0.410976          0.722938
# 29014          0.734490          1.335876    0.822438          0.852257
# 15843          0.590085         -0.066785   -0.339338         -1.087527
# 26577          0.720643          0.326611    0.592503          0.722938
#
#        accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 26438      1.869280      0.400821     -0.839319       1.639417       0.454378
# 24627      2.003704      0.365915     -0.829373       1.979345       0.341077
# 29014      1.802067      0.540444     -0.869160       1.716673       0.539354
# 15843     -0.382328     -0.855789      1.000861      -0.817338       0.482704
# 26577      2.003704      0.365915     -0.799532       1.963894       0.567680
#
#        magnet_belt_z  total_accel_arm  accel_arm_x  accel_arm_y  accel_arm_z  \
# 26438       0.822474        -0.997631    -0.101797    -0.698711     1.415531
# 24627       0.280433        -0.997631    -0.316373    -0.534598     1.153062
# 29014       0.435302        -0.040516    -0.987611    -0.534598     0.508138
# 15843       0.667605         0.533754    -1.125160     1.006246     0.110685
# 26577       1.287080        -1.571901     0.118281    -0.689594     1.025577
#
#        magnet_arm_x  magnet_arm_y  magnet_arm_z  total_accel_dumbbell  \
# 26438      0.173954     -0.025740      0.848099              0.313289
# 24627      0.279996      0.358291      0.662494              0.313289
# 29014     -0.854884      0.852046      0.829538              0.703206
# 15843     -0.904521      0.901921      0.739829             -0.953941
# 26577      0.442444      0.014159      0.684148              0.410768
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 26438         -0.309317          0.503233         -0.804290
# 24627         -0.175927          0.404287         -0.931864
# 29014          0.298346          1.443222         -0.667604
# 15843          0.461377         -0.251231          0.571683
# 26577         -0.220390          0.602179         -0.840740
#
#        total_accel_forearm  accel_forearm_z
# 26438             0.728667         0.381576
# 24627            -0.262625         0.279642
# 29014             1.620829         0.789315
# 15843             0.629537        -1.314908
# 26577             1.918216         0.039367

# %%
# Apply the Logistic Regression Model, SVM and Random Forest to the testing dataset
acc_lr=accuracy_score(clf_lr_gs.predict(X_test_final),y_test)
acc_svm=accuracy_score(clf_svm_gs.predict(X_test_final),y_test)
acc_rf=accuracy_score(clf_rf_gs.predict(X_test_final),y_test)
print('Accuracy Logistic Regression: {}\n\
Accuracy SVM: {}\n\
Accuracy Random Forest: {}'.format(acc_lr,acc_svm,acc_rf))
# Out:
# Accuracy Logistic Regression: 0.744171232004077
# Accuracy SVM: 0.9927379283985222
# Accuracy Random Forest: 0.9992355714103708

# %% [markdown]
# ## Conclusions and Remarks
# <a id='Conclusions_and_Remarks'></a>
# This dataset is very easy to analyze but in my opinion, it is a good exercise to get used to the general data science analysis pipeline.
# * The number of missing values was very low, and as a consequence, the strategy to impute these observations doesn't have an impact on the ML model performance.
# * Few evident outliers (2) were detected in the training data. Because these observations were very extreme I dropped out them directly. Also, I developed a univariate and multivariate analysis to find others "not such evident" outliers, but the performance of the ML algorithms doesn't improve if these values were erased from the training dataset.
# * The model with the worst performance was Logistic Regression, while SVM and Random Forest obtained very closes accuracy in the training and validation dataset. This is evidence that exist a nonlinear relationship between the dependent and independent variables.
# * Finally, the implemented pipeline was proved over the test dataset, where the SVM and Random Forest alternatives obtained better results with accuracy > 0.99.

# %% [markdown]
# ## Supplementary Information
# <a id='Supplementary_Information'></a>

# %% [markdown]
# ### Other anomaly detection approaches

# %%
# Principal Components Analysis for Visualization
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(X_train)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2',
                         'principal component 3'])

# %%
# Compute the percent of outliers with univariate IQR method
from functions import iqr_rule 
predictions_iqr = X_train.apply(iqr_rule,axis=0).all(axis=1)
print('With the IQR criterium {:2f}% of the observations are outliers.'\
      .format(100*sum(predictions_iqr)/len(predictions_iqr)))
# Out:
# With the IQR criterium 28.540140% of the observations are outliers.

# %%
# Results Interquantile Range
plt.scatter(principalComponents[:,0],principalComponents[:,1],label='Points')
plt.plot(principalComponents[predictions_iqr,0],principalComponents[predictions_iqr,1],'r.',label='Outliers')
plt.legend()

# %%
# Fit the isolation Forest
clf = IsolationForest(random_state=0).fit(X_train)
# Make the predictions
predictions_if=clf.predict(X_train)
print('With the Isolation Forest criterium {:3f}% of the observations are outliers.'\
      .format(100*sum(predictions_if==-1)/len(predictions_if)))
# Out:
# With the Isolation Forest criterium 10.317776% of the observations are outliers.

# %%
# Results Interquantile Range
plt.scatter(principalComponents[:,0],principalComponents[:,1],label='Points')
plt.plot(principalComponents[predictions_if==-1,0],
         principalComponents[predictions_if==-1,1],'r.',label='Outliers')
plt.legend()

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.scatter(principalComponents[:,0],principalComponents[:,1],
            principalComponents[:,2],label='Points')
ax.scatter(principalComponents[predictions_if==-1,0],principalComponents[predictions_if==-1,1],
       principalComponents[predictions_if==-1,2],'r.')

# %%
from sklearn.neighbors import LocalOutlierFactor
lof = LocalOutlierFactor(novelty=True)
lof.fit(X_train)
# Make the predictions
predictions_lof=lof.predict(X_train)
print('With the Local Outlier Factor criterium {:3f}% of the observations are outliers.'\
      .format(100*sum(predictions_lof==-1)/len(predictions_lof)))
# Out:
# With the Local Outlier Factor criterium 1.636668% of the observations are outliers.

# %%
# Results Local Outlier Factor
plt.scatter(principalComponents[:,0],principalComponents[:,1],label='Points')
plt.plot(principalComponents[predictions_lof==-1,0],
         principalComponents[predictions_lof==-1,1],'r.',label='Outliers')
plt.legend()
